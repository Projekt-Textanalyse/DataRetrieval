# %%
import os
import xml.etree.ElementTree as ET

# %%
import pandas as pd
import os
import google.oauth2.credentials
import google_auth_oauthlib.flow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-bbdadb3d203c> in <module>
#       1 import pandas as pd
#       2 import os
# ----> 3 import google.oauth2.credentials
#       4 import google_auth_oauthlib.flow
#       5 from googleapiclient.discovery import build
#
# ModuleNotFoundError: No module named 'google'

# %%
CLIENT_SECRETS_FILE = "client_secret.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'
def get_authenticated_service():
    flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)
# Remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
    good_kwargs = {}
    if kwargs is not None:
        for key, value in kwargs.items():
            if value:
                good_kwargs[key] = value
    return good_kwargs

# %%
client = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=692697523900-m6jnb73lek6udl104gvou0joh8t0771q.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=O2rgDFrfJ5kVY062gbALmtf5oW3yKz&prompt=consent&access_type=offline
# Enter the authorization code: 4/0AEtq3xJseFOZUi2wEx63TZEGh4StR31UgrWxjuRbZDDaHq9cMuUe7Y

# %%
def youtube_keyword(client, **kwargs):    
    kwargs = remove_empty_kwargs(**kwargs)
    response = client.search().list(
        **kwargs
        ).execute()    
    return response

# %%
def youtube_search (criteria,max_res):   
    #create lists and empty dataframe
    titles = []
    videoIds = []
    channelIds = []
    resp_df = pd.DataFrame()
    
    while len(titles) < max_res:
        token = None
        response = youtube_keyword(client,
                        part='id,snippet',
                        maxResults=50,
                        q=criteria,
                        videoCaption='closedCaption',
                        type='video', 
                        #videoDuration='long',
                        #I18nRegion='de',
                        pageToken=token,
                        relevanceLanguage='de',
                        regionCode='de') 
                                         
        for item in response['items']:        
            titles.append(item['snippet']['title'])
            channelIds.append(item['snippet']['channelTitle'])
            videoIds.append(item['id']['videoId'])
        
        token = response['nextPageToken']
        
    resp_df['title'] = titles
    resp_df['channelId'] = channelIds
    resp_df['videoId'] = videoIds
    resp_df['subject'] = criteria
    
    return resp_df

# %%
Gates_Videos = youtube_search('[Impfen+Bill+Gates]',10)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-37-583ea5e231a1> in <module>
# ----> 1 Gates_Videos = youtube_search('[Impfen+Bill+Gates]',10)
#
# <ipython-input-35-9aa01f730821> in youtube_search(criteria, max_res)
#      18                         pageToken=token,
#      19                         relevanceLanguage='de',
# ---> 20                         regionCode='de')
#      21
#      22         for item in response['items']:
#
# <ipython-input-16-df3a6a419a84> in youtube_keyword(client, **kwargs)
#       2     kwargs = remove_empty_kwargs(**kwargs)
#       3     response = client.search().list(
# ----> 4         **kwargs
#       5         ).execute()
#       6     return response
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     905             callback(resp)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
#     908         return self.postproc(resp, content)
#     909
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/search?part=id%2Csnippet&maxResults=50&q=%5BImpfen%2BBill%2BGates%5D&videoCaption=closedCaption&type=video&relevanceLanguage=de&regionCode=de&alt=json returned "Daily Limit Exceeded. The quota will be reset at midnight Pacific Time (PT). You may monitor your quota usage and adjust limits in the API Console: https://console.developers.google.com/apis/api/youtube.googleapis.com/quotas?project=692697523900">

# %%
Gates_Videos.loc[0:40]
# Out:
#     Unnamed: 0                                              title  \
# 0            0                    Bill Gates will die Welt impfen
# 1            1              Bill Gates und  Bevölkerungskontrolle
# 2            2  Wie Bill Gates das Weltgesundheitssystem monop...
# 3            3                   Innovating to zero! | Bill Gates
# 4            4  Bill Gates on Fighting Coronavirus | The Daily...
# 5            5            Dok 1 - &quot;Impfen? Nein danke!&quot;
# 6            6  Bill Gates at MIT 2010 - &quot;Giving Back: Fi...
# 7            7  Jens Spahn im Interview mit YouTubern bei Brea...
# 8            8  Online-Bürgersprechstunde mit Ministerpräsiden...
# 9            9   Corona: die krassesten Thesen und Lügen | STRG_F
# 10          10  Corona Virus (COVID-19) discussion with Bill G...
# 11          11  Coronavirus-Update #26: Genbasierte Impfstoffe...
# 12          12  Gates kaapt Duitsland en de rest van de wereld...
# 13          13                       „Verantwortung in der Krise“
# 14          14  Coronavirus-Update #35: Vielversprechende Impf...
# 15          15  Halle (Saale): Video-Pressekonferenz vom 19. A...
# 16          16  How we must respond to the coronavirus pandemi...
# 17          17      #21 Gute Nachrichten! aktuell | The Good News
# 18          18  Coronavirus-Update #36: Die Rolle von Kindern ...
# 19          19  HIRSCHHAUSEN ZU HAUS vom 18. Mai 2020 | Eckart...
# 20          20  Coronavirus-Update #31: Eine Wiederinfektion b...
# 21          21  Pressebriefing der Sächsischen Staatsregierung...
# 22          22  Servus TV Talk mit Prof. Dr. Sucharit Bhakdi -...
# 23          23  Coronavirus-Update #32: Jetzt mit Hochdruck Fo...
# 24          24  Gebärdensprachvideo: AfD-Anträge zu Grund­rech...
# 25          25  Coronavirus-Update #33: Herdenimmunität noch l...
# 26          26  „Coronavirus-Impfstoff: milliardenschwerer Pha...
# 27          27      Mosquitos, malaria and education | Bill Gates
# 28          28  Dr. med. Dietrich Klinghardt über COVID-19, St...
# 29          29           Poetry Slammer: MATZE B. at TEDxBodensee
# 30          30  Extra 3 Spezial | 06.05.2020 mit Sarah Kuttner...
# 31          31  CORONAVIRUS 😷 2019-nCoV 🤧 ¦¦ Wir sind der VIRU...
# 32          32  Extra 3 vom 07.05.2020 mit Christian Ehring im...
# 33          33  We Asked The World’s Leading Vaccine Expert Ab...
# 34          34                  Visite | 21.4.2020 | Visite | NDR
# 35          35  Von Corona zum Gemeinwohl - Folge 4 - Artenvie...
# 36          36  &quot;Pandemie&quot;?! Eine schwache Saison Gr...
# 37          37  ZAPP: Hygienedemos, Sparkurs, Drehs in Zeiten ...
# 38          38  Bill Gates vs Earth: un filantropo samaritano ...
# 39          39  Bill Gates hijacks Germany and the world (KenF...
# 40          40  Politik der Gegenwart - Wer regiert die Welt? ...
#
#                                             channelId      videoId  \
# 0                                        veggietation  AhuU_CG9v80
# 1                                        veggietation  YWjkYM8slFU
# 2                                        veggietation  QVYj1HQyPg0
# 3                                                 TED  JaF-fq2Zn7I
# 4                     The Daily Show with Trevor Noah  iyFT8qXcOrM
# 5                                    Christian Tieber  8nH_0sauWxk
# 6                               MIT Video Productions  bfIqbOi9RCQ
# 7                    Bundesministerium für Gesundheit  RsP9AuKKu20
# 8                                    FreistaatSachsen  O8iMjdBFY3A
# 9                                              STRG_F  3duErFbfFM0
# 10                                       Khan Academy  NDnjXdDxEhk
# 11                                       NDR Ratgeber  lhujYBcgbKo
# 12                             Wolfgang van den Akker  57_NwZqW5nc
# 13                                        RegierungBW  BMNkGoYrdTs
# 14                                       NDR Ratgeber  0qsxDbSYz0c
# 15                                    StadtHalleSaale  o0scbzPHFtM
# 16                                                TED  Xe8fIjxicoo
# 17                               TOS Gemeinde Leipzig  zfsjxmraiwk
# 18                                       NDR Ratgeber  _N-XK6u7mIQ
# 19                            Eckart von Hirschhausen  TW2RoAvihOY
# 20                                       NDR Ratgeber  nD5EtGYU_nY
# 21                                   FreistaatSachsen  V0J94vF_rZ4
# 22                                    Kölner Karneval  xc-e8zaxicQ
# 23                                       NDR Ratgeber  _pP8AfANjHc
# 24                                Deutscher Bundestag  joqd-Mvpa6E
# 25                                       NDR Ratgeber  DSeZYVYd_DU
# 26                                       klagemauerTV  0bhAXcQV8Os
# 27                                                TED  tsgvhP07BC8
# 28                   QS24 - Schweizer Privatfernsehen  neY5UrYKYk0
# 29                                         TEDx Talks  KG9tm2Z4W-Y
# 30                                            extra 3  Hdp_mi_QA3o
# 31                                              Utler  6RRYqN5hbkw
# 32                                            extra 3  8s3hU3YDh3A
# 33                                         Asian Boss  5cYWd0N8nO4
# 34                                       NDR Ratgeber  Flm-dLvIw80
# 35                                   Christian Felber  yrb8gSAw8_M
# 36                                     Lumira HEALING  0uFYpyfYaXQ
# 37                           ZAPP - Das Medienmagazin  GXl6PPr_UmY
# 38                              Il Progetto Risveglio  8-etktBzFos
# 39                                      Truth Seekers  m7qjJDbL0wI
# 40  Bridgecreation Der Podcast der Menschen verbindet  DbYp7lVctR8
#
#            subject
# 0   [Impfen+Gates]
# 1   [Impfen+Gates]
# 2   [Impfen+Gates]
# 3   [Impfen+Gates]
# 4   [Impfen+Gates]
# 5   [Impfen+Gates]
# 6   [Impfen+Gates]
# 7   [Impfen+Gates]
# 8   [Impfen+Gates]
# 9   [Impfen+Gates]
# 10  [Impfen+Gates]
# 11  [Impfen+Gates]
# 12  [Impfen+Gates]
# 13  [Impfen+Gates]
# 14  [Impfen+Gates]
# 15  [Impfen+Gates]
# 16  [Impfen+Gates]
# 17  [Impfen+Gates]
# 18  [Impfen+Gates]
# 19  [Impfen+Gates]
# 20  [Impfen+Gates]
# 21  [Impfen+Gates]
# 22  [Impfen+Gates]
# 23  [Impfen+Gates]
# 24  [Impfen+Gates]
# 25  [Impfen+Gates]
# 26  [Impfen+Gates]
# 27  [Impfen+Gates]
# 28  [Impfen+Gates]
# 29  [Impfen+Gates]
# 30  [Impfen+Gates]
# 31  [Impfen+Gates]
# 32  [Impfen+Gates]
# 33  [Impfen+Gates]
# 34  [Impfen+Gates]
# 35  [Impfen+Gates]
# 36  [Impfen+Gates]
# 37  [Impfen+Gates]
# 38  [Impfen+Gates]
# 39  [Impfen+Gates]
# 40  [Impfen+Gates]

# %%
import pandas as pd
vid_ids = pd.read_csv('idlst.csv')

# %%
vid_ids = vid_ids.loc[:,'0'].tolist()

# %%
len(vid_ids)
# Out:
# 540

# %%
def get_all_ccs(videos):
    base_url = 'https://www.youtube.com/watch?v='
    #lang="de"
    for vid in videos:
        url = base_url + vid
        cmd = ["youtube-dl","--skip-download","--write-sub",url]
        os.system(" ".join(cmd))

# %%
len(set(vids))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f8264994403d> in <module>
# ----> 1 len(set(vids))
#
# NameError: name 'vids' is not defined

# %% [markdown]
# #### Using the above created function

# %%
get_all_ccs(vid_ids)

# %%
sub_vids
# Out:
# ['sYT0A26wsxQ', '72plsUzUjP4']

# %%
vids = [item[0] for item in Gates_Videos.values.tolist()]

# %%
filenames_vtt
# Out:
# ['¿Por qué nadie habla de Jeffrey Epstein, Bill Gates & la vacuna del coronavirus-QYEz_0hhrVI.es-ES.vtt',
#  'Bill Gates talks about Paul Allen during speech at new UW computer science building-S01f6MuBCtE.en.vtt',
#  'A Global Cashless Society has been the Goal of the Bill Gates Foundation Since 2012-xrNzbrYuCOE.en-GB.vtt',
#  "Bill and Melinda Gates' 2014 Stanford Commencement Address-wug9n5Atk8c.en.vtt",
#  'Bill Gates on Finding a Vaccine for COVID-19, the Economy, and Returning to ‘Normal Life’-5oEcxMfwJnw.en.vtt',
#  'Bill Gates krijgt zijn vermogen niet weggegeven • Z zoekt uit---kmm2el4tE.nl.vtt',
#  "Bill Gates's Heroes in the Field - Nandan Nilekani-q_I5oj9LEh8.en.vtt",
#  'Bill Gates On Changing Behaviors To Fight Covid-19 _ The Last Word _ MSNBC-aMU5AlwlaKE.en.vtt',
#  'RAMALAN BILL GATES...!!! Bill gates sudah meramal adanya SUPER VIRUS dari CHINA-c4STlP-yHcE.en.vtt',
#  'Bill Gates meet Mark Zuckerberg Finally heading back to school Memory-4anZ2tY6J5g.zh-CN.vtt',
#  'Bill Gates on the good news about fake news-OzsjvQAk-eA.en.vtt',
#  'Bill Gates discusses foundation efforts, UCF online program-WmPUF4Bqb9A.fr.vtt',
#  'SIEĆ 5G ,Bill Gates i REPTILIANIE HAKUJĄ MI KONTO-bRD4BGec0wU.pl.vtt',
#  'Bill Gates Pushes Students Toward Philanthropy-w4UO1cbNj7Y.en.vtt',
#  "Passing of the Gavel 2019 - Chairman's Speech (Bill Gates)-5A8AK8CTxAo.en.vtt",
#  "Adam Ruins Everything - Why You Won't Drop Out and Become Bill Gates _ truTV-bXM3a1dSIhM.en.vtt",
#  'How Bill Gates remembers what he reads-8xwh88cI_d8.en.vtt',
#  "Why giving away our wealth has been the most satisfying thing we've done... _ Bill and Melinda Gates-aSL-iIskEFU.en.vtt",
#  "The Big Bang Theory 11x18 Promo 'The Gates Excitation' (HD) ft. Bill Gates-ivt6sz7yxG4.en.vtt",
#  'Trevor Noah Trained with Pro Tennis Coaches to Play Against Roger Federer-37lqCgW1h9o.en.vtt',
#  'Bill Gates on the importance of media-A3qOnvNa6Ic.en.vtt',
#  'Success Habits of Billionaires - Warren Buffett, Elon Musk, Bill Gates, Steve Jobs, Mark Zuckerberg-MoykduZa4Y0.en.vtt',
#  'Líder Local previu Isolamento forçado aos que não tomarem a Vac_na! (2009) -clique CC leg PT no APP-nVpWXB5IQLw.pt-BR.vtt',
#  'Robert F. Kennedy Jr. exposes Gates plan to control global health policy-6TffC_aPLwU.en.vtt',
#  'Holiday Books 2016-FW00Osyz_IA.en.vtt',
#  'The Corbett Report - Bill Gates and the Population Control Grid [SUB ITA]-jvLcWSYGyJ8.it.vtt',
#  'Motivational Speech in Hindi I Bill Gates I Success Quotes I By Coach Juned-pFwHIgsW1qo.hi.vtt',
#  'Why we swing for the fences _ Our 2020 annual letter-aL-XteoutNU.en.vtt',
#  'Bill Gates und  Bevölkerungskontrolle-YWjkYM8slFU.de.vtt',
#  'Coronavirus _ History of Pandemics _ Bill Gates Point of View _ Epidemics _ History _ Information--GhKEWuDc_M.en.vtt',
#  'Bill Gates and John Green Discuss Global Health-bYv_nMQIGDw.en.vtt',
#  "'A Conversation with Bill Gates' Q&A at Harvard University-ofQMbC2e_as.en.vtt",
#  'BERNARD ARNAULT _ BIOGRAPHY IN HINDI _ SECOND RICHEST MAN _ BILLGATES ON THREE _ DOCUMENTRY-YhHKwXU8kXk.en-GB.vtt',
#  'First Minister meets Bill Gates-hwBe-WpT4Zo.en-GB.vtt',
#  'Gates Janicki Omniprocessor-p-UaKGISXjQ.en.vtt',
#  'Bill Gates talks about eradicating polio-UTd-Fs0_UtE.en.vtt',
#  "Who's bill gates-cfUCA-OljWc.en.vtt",
#  'Bill Gates Offers 100k For Best Condom Ever-OtfEwkwCyUo.en.vtt',
#  'Do You Need To Be Rich To Be Healthy (ft. Bill Gates)-PCTVL5oKlik.en.vtt',
#  'COVID 19 ID 2020 BILL GATES-EBfjDsxLuuE.es-ES.vtt',
#  'Corbettreport - deutsch - Wer ist Bill Gates-lz4dDKSizGg.de.vtt',
#  'Donald Trump vs Bill Gates - People _ Celebrity Comparison-C6EWtvp_6Io.en.vtt',
#  'Bill Gates aceita o desafio do balde de gelo (legendado)-GxiwCXrHiHg.pt.vtt',
#  'Bill Gates - Gelecek ile İlgili Görüşler (Büyük Tarih Projesi)-mTxb8gVNjO0.tr.vtt',
#  "Bill Gates .'ahora no queremos tener muchas personas recuperadas, ya sabes ' (activar subtitulos )-m1XtAkleVhk.es.vtt",
#  'Bill Gates remembers his early programming career-vYXQTrYPenQ.hy.vtt',
#  'O VISIONÁRIO DO SÉCULO (BILL GATES)-fSvJHTTlA7w.en-US.vtt',
#  "Bill Gates To Guest Star On 'Big Bang Theory'-Mi1OmhtaPKQ.en.vtt",
#  'How Magnus Carlsen checkmated Bill Gates in 9 moves-_0QdI0rVoHA.en.vtt',
#  "Melinda's new book-5TXr0AWKlLc.en.vtt",
#  'Bill Gates on Artemisinin Project-oh29ZxZrH_I.en.vtt',
#  'BILL GATES - O PLANO PARA VACINAR O MUNDO INTEIRO (legenda PORT no APP e computador - clique CC-)-fpZGzeFTBbY.pt-BR.vtt',
#  'The deadliest animal in the world-UI60HV6vQIg.en.vtt',
#  'See Bill Gates’ Chilling Pandemic Warnings To Trump – Before The Coronavirus Outbreak Hit _ MSNBC-eEup9pErtmM.en.vtt',
#  "Alex's Bill Gates Chicken Neck Bastard Rant with Subtitles-W_hq1bnc7J8.en.vtt",
#  'DIE WAHRHEIT über SRF, Bill Gates und das System!! (Anschauen bevor es gelöscht wird!!)-iqB8Quc8A9g.de.vtt',
#  'MLG Steam Summer Sales - Gaben Vs. Bill Gates-8KA66_w7Yc8.en.vtt',
#  "Bill Gates talks 1-on-1 about ending polio, driving the kids to school, and Melinda Gates' new book-L7JRqspJStQ.en.vtt",
#  'Bill & Melinda Gates - Our Big Bet-7DmpncBDibA.en.vtt',
#  'Players of the Cabal _ Deep State Department 👁 Bill Gates  Donald Trump Anthony Fauci-lCkIjYhAdHA.en.vtt',
#  'Bill Gates - Global Innovation Is The Key To Achieving A Return To Normal-dNiuaKKEPu8.en.vtt',
#  'Bill Gates Inspirational Quotes_ Top10 Motivational Quotes by Bill Gates _ Bill Gates Quote-1jsXwm9wZwE.en.vtt',
#  'Bill Gates open letter to Homebrew Computer Club-JLYlBXuyHFs.en.vtt',
#  'Bill Gates - Entvölkerung durch Impfungen-PaxvrvRw0dA.de.vtt',
#  'Bill Gates - AIDS-free generation is decades away-ebcdF_NRESw.en.vtt',
#  'Bill Gates vs the Average American - How Do They Compare - Celebrity Comparison-PajyImF5vIM.en.vtt',
#  'Waarom Bill Gates geen aansprakelijkheid wil. Ben jij bereid het risico te nemen-7LdF11Bm-4Q.nl.vtt',
#  'Bill Gates adds $100m, as Polio nears eradication-3tCUWbhyiig.en.vtt',
#  'Bill Gates in 2015 - A deadly flu epidemic is the biggest threat to humanity-TSbNMrGwrmo.es-ES.vtt',
#  "Bill Gates' message on #COVID19 to the southern hemisphere-2CC5ejfjFq4.en.vtt",
#  "Hans Rosling's Demographic Party Trick #1, with Bill Gates-2nDh8MQuS-Y.en.vtt",
#  "Inside Bill's Brain - Decoding Bill Gates _ Official Trailer _ Netflix-aCv29JKmHNY.en.vtt",
#  'Oculta mondială a decis!  _ Bill Gates _  Vaccinurile si efectele lor!-HoNTsh3Pjp4.en.vtt',
#  'Próxima Pandemia - No estamos listos (Bill Gates)-441BdVehC8U.en-US.vtt',
#  'What will it take to end malaria Bill Gates and George Osborne discuss.-AS_qx_E64wE.en.vtt',
#  'Bill Gates und das Coronavirus - eine Lovestory-BcZ0IqchlVQ.en.vtt',
#  'A Conversation with Bill Gates Hosted by Eric Horvitz-wdy3EBBRsJA.en-US.vtt',
#  'How To Repeat The Success of Bill Gates in 6 months Bill Gates shared the secrets of success-id1ryXAgygE.en.vtt',
#  'Em 2015 Bill Gates Alerta Sobre uma Grande Epidemia--dX9qEqEqGA.pt.vtt',
#  "Vaccins et Covid-19  - Bill Gates et l'OMS en flagrant délit de corruption-o64Hm8YFHww.fr-FR.vtt",
#  'Bill Gates’ 7 Secrets of Success-GQJWRpZolzY.en.vtt',
#  "Bill Gates' Wealth Visualized & 1,000,000 Subscriber Announcement-bF7i1XmZvr4.en.vtt",
#  'Bill Gates and Prediction 2021 _ China 2.0 _ Tamil Pokkisham _ Vicky _ TP-XMfaJ4aJIls.en.vtt',
#  'Bill Gates nadaljuje delo Monsanta; Vandana Shiva v intervjuju za FRANCE 24--iRpz-LUmgE.en.vtt',
#  'Italy Government Says Arrest Bill Gates (Eng Sub) _ Sara Cunial Mind Blowing Step _ Fact Table-CgYTeXtQbds.en.vtt',
#  "Bill Gates on the spread of 'fake news' online-mYTeeZnf43w.en.vtt",
#  "Bill Gates's Top 10 Rules For Success (@BillGates)-wq-gba5nMrc.en.vtt",
#  'Bill Gates on the Humanities-1GAVXoRF8MI.en.vtt',
#  'A Brave independent parliamentary SARA CUNIAL drag BILL GATES, SOROS and more on the prison bars!-MgnPFncOE8o.en-GB.vtt',
#  'Illuminati & Modern Medicine _ Bill Gates Depopulation _ Medical Business _  Mersal _ in Tamil-vJYweyRixUs.en.vtt',
#  "Bill Gates' Beef With Climate Change _ Vegan News _ LIVEKINDLY-WpwJtdcYkAA.en.vtt",
#  'The Buildup to Impact _ Mark Zuckerberg, Bill Gates & Simon Sinek-CRyGofTjKMU.en.vtt',
#  'Bill Gates - La humanidad podría enfrentar una pandemia pronto. (sub esp)-6YP7kYdn7dU.es.vtt',
#  'BILL GATES - All you need to know-eQyiRjIXNk8.en.vtt',
#  "Bill Gates Calls Control-Alt-Delete Shortcut a 'Mistake'-VFphpY_3hk8.en.vtt",
#  '10 CHOSES LES PLUS CHÈRES QUE BILL GATES POSSÈDE _ Delta Agency Media réussite-TJVL6P2P4pU.fr.vtt',
#  "Bill Gates talks 1-on-1 about ending polio, driving the kids to school, and Melinda Gates' new book-dCFRetLvv4U.en.vtt",
#  'Bill Gates Chats with Ellen for the First Time-f5NJQiY9AuY.en.vtt',
#  'Bill Gates Predicted a Pandemic like the CoronaVirus in 2015 _ Ted Talks Speech _ YaaNa _ CC-VoQo1jqGr80.en.vtt',
#  'Bill Gates & Warren Buffett-L_6jATen490.en.vtt',
#  "Inside Bill's Brain _ Ending Scene Decoding Bill Gates-1f-iRuLV4mY.en.vtt",
#  'Bill Gates - Teachers need real feedback-81Ub0SMxZQo.en.vtt',
#  'Success Reveal - The richest man in the world biography BILL GATE-UgwagILYR7c.en.vtt',
#  'This partnership helped prevent 13 million deaths-DyIH3O0NRsM.en.vtt',
#  'Bill Gates le responde al p_ de Linux-wUG4DMlwheA.en.vtt',
#  "Bill Gates Wasn't Impressed With Donald Trump-UUrddqT9i_s.en.vtt",
#  'Deputada Sara Cunial do Parlamento Italiano denuncia Bill Gates-QIf4idTBz7E.pt-BR.vtt',
#  'Bill Gates, Elizabeth Warren On Same Side Of Wealth Tax Debate _ The Last Word _ MSNBC-IXiPqCZsN2M.en.vtt',
#  'Bill Gates and Eddie Donovan Microsoft 1999 Interview-ws7FT3sGvZ8.en.vtt',
#  'Leadership & World Change with Barack Obama-9buDC32fKw0.en.vtt',
#  "'PR3ND4M BILL GATES +470.000 views. (A mídia não mostra, mas é trend mundial) LegendaPORT no APP -CC-U-onOPOIV60.pt-BR.vtt",
#  'The plans of the #globalistelite _ #plandemic #pandemic #ID2020 #billgates #neuralink #event201 #1%-8SGWjHazPyE.en.vtt',
#  "Bill Gates on his 2015 'virus' warning, efforts to fight coronavirus pandemic-jXHikITwlng.en.vtt",
#  'Why Snoop Dogg is mad at Bill Gates-jvmvtUijW50.en.vtt',
#  'The Man Who COULD Have Been Bill Gates [Gary Kildall]-sDIK-C6dGks.en.vtt',
#  'Bill and Melinda Gates - Our 2016 Annual Letter-9XcHGEIky5o.en.vtt',
#  'How we must respond to the coronavirus pandemic _ Bill Gates-Xe8fIjxicoo.en.vtt',
#  'Đọc sách như Bill Gates - Bạn có hứng thú-IM_g6YZnOPQ.vi.vtt',
#  "Let's put birth control back on the agenda _ Melinda Gates-2BOTS9GAjc4.en.vtt",
#  'Bill Gates meets Aamir Khan-6XJBwbf5F3M.en.vtt',
#  'Bill Gates On Coronavirus - ‘It’s Going To Be A While Before Things Go Back To Normal’ _ TODAY-tEhlnIt5rbU.en.vtt',
#  'The Best Way to Reset - The Bill Gates Method-ZcGVQPYKSiU.en.vtt',
#  'Bill Gates on the Industries of the Future and Artificial Intelligence-lIjj86LcDnI.en.vtt',
#  'Wie Bill Gates die Weltgesundheit monopolisierte.Corbett T.1 Exzellente Analyse. UNTERTITEL-sw4szXqz0Ro.de.vtt',
#  'Bill Gates, Zwangsimpfung und die Corona-Biowaffe aus China _ Possoch klärt _ BR24-lkJyPPkD2_U.de.vtt',
#  'Microsoft Success Story (Ft. Bill Gates) _ Motivational Speech _ Bill Gates Interview-A04oCqcvqxA.en.vtt',
#  'The God & Devil Show - Bill Gates Cartoons.-eXIDuTESMCk.en.vtt',
#  'Come Bill Gates ha monopolizzato la sanità globale SUB ITA-DuV5aJT-TYo.it.vtt',
#  'Beethoven as Bill Gates - Jose Bowen at TEDxSMU 2011-Jl3gnP4uG2o.en.vtt',
#  'Code Break 5 0  Simulations and Data with Bill Gates   Part 1   Interpreted-g19flNptpxQ.en-US.vtt',
#  'Bill Gates leben und karierre _ Berühmte Personen Kana-0nK2ok1LtD0.de-DE.vtt',
#  'Bill Gates Apologies For ‘Control+Alt+Delete’-Gl9ykzKSDPo.en.vtt',
#  'A conversation with Bill Gates and Tara Westover-a7Y6Udf_Nzo.en.vtt',
#  'Khan Academy on the Gates Notes-UuMTSU9DcqQ.en.vtt',
#  'IS BILL GATES WORKING FOR THE BEAST IS CORONA VIRUS A GATEWAY FOR THE BEGINNING OF THE END-vnW7MNjtFME.en.vtt',
#  'BILL GATES Speech at Harvard University _ Motivational Speech by BILL GATES-OaYuZVICKdI.en.vtt',
#  'Motion to arrest Bill Gates in Italian Parliament-zGrry9a6KfM.af.vtt',
#  'Advice on Ways to Focus _ Essentialism, Bill Gates & LinkedIn-OWtWGmOePtI.en-GB.vtt',
#  'Bill Gates talks about the impact teachers have had on his life and career.-8rZSkVa9zoE.en.vtt',
#  'Bill Gates’s Heroes in the Field - Pashu Sakhis-TQ9RZfjitSQ.en.vtt',
#  'Bill meets bots-tMwhLIVPUE8.en.vtt',
#  'Bill Gates what are you up to-ImSBdJVTCO8.en-US.vtt',
#  'Leonardo da Vinci’s Notebook - The Codex Leicester-zwGdnCNi8Ss.en.vtt',
#  'Sweet Nostalgia with Warren Buffett and Bill Gates-DjOXpbpPU-U.en.vtt',
#  'Goalkeepers 2019 - Panel discussion Jacinda Ardern, Pedro Sánchez, and Bill and Melinda Gates.-Y5eo5-cJt0U.en.vtt',
#  'Bill Gates - ‘I’d Like To See Schools Reopened In September’ _ The Last Word _ MSNBC-KUHrBG2Me-M.en.vtt',
#  'What Does Bill Gates Carry Around in His Wallet-6usVX6BJYEk.en.vtt',
#  'Triff Bill Gates-jIM5o-GdGKw.de.vtt',
#  'Scanning for answers to a pandemic-xtY4ThJ9i9E.en.vtt',
#  'VACINAÇÃO OBRIGATÓRIA E RASTREAMENTO ELETRÔNICO (LEGENDA PORT no APP e computador - clique CC)-WUF6c1uAlfw.pt.vtt',
#  'HOW MACHINES WILL CHANGE THE WORLD _ Elon Musk, Bill Gates & Mark Zuckerberg-qU5KY0OLwts.en.vtt',
#  'பில் கேட்ஸ் உண்மை முகம் _ Baby Bill Gates _ Tamil Pokkisham _ Vicky _ TP-ALOPIiMTZ1c.en-GB.vtt',
#  'Pourquoi Bill Gates est devenu la cible favorite des complotistes-K5SPfG2vErQ.fr.vtt',
#  "Bill Gates' favorite burger-QOroEl3dUKA.en.vtt",
#  'The First Thing Bill Gates Bought When He Got Rich-jedRHPKhso0.en.vtt',
#  'Coronavirus Patent from the Pirbright Institute, Bill Gates and the Coronavirus Patents of the CDC-19ndIlGdQqA.en.vtt',
#  'How Microsoft Saved Apple (And Why They Did It)-H_SXtJf2oz4.en.vtt',
#  'President Moon, Bill Gates agree to cooperate in developing COVID-19 treatments-6dqvTgKSInU.en.vtt',
#  'Corona-Impfstoff - Hatte Bill Gates Vorwissen über die „Pandemie“ _ 21.03.2020 _ www.kla.tv_15915-IUAc_cj6-2s.de.vtt',
#  'Bill Gates _ De la philanthropie à la solidarité internationale _ Forum Café Solidays-d_gZwMr2Uuk.fr.vtt',
#  'Bill Gates Exclusive Interview - Chairman of Microsoft-Plf7fQ-cmz8.en.vtt',
#  'CNN - Breaking News - Bill Gates talks with Richie From Boston and Dr. Kaufman-1MbHoM3Izwo.en.vtt',
#  'Hoe Bill Gates de wereldwijde gezondheid monopoliseerde-c7zJSRTcwrY.en.vtt',
#  'Bill Gates is Illuminati-bcCshuGMPUA.en.vtt',
#  "Bill Gates Isn't Too Happy with Google's Project Loon-aVtD0swv94c.en.vtt",
#  'Bill Gates finanziert massive Impfkampagne durch YouTube-Influencer (with English subtitles)-wyV-W4GQXTc.en-GB.vtt',
#  'ביל גייטס אוהב חיסונים - Vaccine - Bill Gates-oef5YexoLck.iw.vtt',
#  'BILL GATES - Uma Historia de Sucesso - [Documentário Completo Dublado] HD-9AVAiJT6-Ho.pt-BR.vtt',
#  "Bill Gates'e Göre Yakın Geleceğin Teknolojileri-mdiQtv4UFk4.tr.vtt",
#  'MENSAJE COMPLETO DE ANONYMOUS PARA BILL GATES - COVID19 SUBTITULADO AL ESPAÑOL-43LiB6Ynmmw.en.vtt',
#  '5 books to read this summer-gTjXTRz4dDw.en.vtt',
#  'What is Creativity (with Bill Gates, Malala, Rosario Dawson, Lisa Loeb and Susan Wojcicki)-VYqHGIR7a_k.en.vtt',
#  'LEARN ENGLISH _ BILL GATES - Harvard Commencement Address (English Subtitles)-KMEe2ni92rQ.en.vtt',
#  'Steve Jobs and Bill Gates Together at D5  Full Video (english subtitles)--v41lgjRMjY.en.vtt',
#  "'Build the BEST PRODUCTS!' - Bill Gates (@BillGates) - #Entspresso-YR5QS6n5494.en.vtt",
#  'How To Be As Productive As Bill Gates - 5 Proven Practices-vqqVbU0nkOE.en.vtt',
#  'Deep State, NWO,  Bill Gates, Agenda 21 at Italian Chamber of Deputies-qN6bwZE0v-c.en.vtt',
#  'Bill Gates Holds Up Jar of Poop To Talk About New Toilet Technology-CoWhG7VARvQ.en.vtt',
#  'President Moon, Bill Gates agree to work together on COVID-19 treatments-vOTevs0pblc.en.vtt',
#  '7 miljardia ihmistä tarkoitus rokottaa RNA-rokotteella - Bill Gates tv´ssä 12.04.2020 - Suomitekstit-gWWDexIJ8mM.fi.vtt',
#  'Tài Sản Bill Gates 2019 - Bạn Sẽ Không Tin Được Ông Làm Gì Với Tiền Của Mình…-oKruxnK9UAE.vi.vtt',
#  'Trevor Noah - Human Capital is Changing the Future-0gLMiuywApw.en.vtt',
#  'When your closest colleague is also your husband-DIII3QDmR3k.en.vtt',
#  'A conversation with Bill Gates and Francis Collins on global health and genomics at #ASHG17-coexWzUAoh8.en.vtt',
#  'Bill Gates on Life-_R8bI4ZzSZ8.en.vtt',
#  'Bill Gates - Population dilution - ביל גייטס - דילול אוכלוסין-DdY-uI2NBmI.iw.vtt',
#  'Africa is the youngest continent-WO2yLOpJaK0.en.vtt',
#  "Bill Gates to attend wedding of Dangote's daughter-ugc3ZUZsP84.en.vtt",
#  "Discours au parlement d'une italienne exigeant l'arrestation du «criminel Mr vaccin» Bill Gates...-il7RJ9BmGOg.en.vtt",
#  'Bill Gates’s Heroes in the Field - Dr. Agnes Binagwaho-F7d3mCdXR4k.en.vtt',
#  '¿Bill Gates No APRUEBA El MATRIMONIO De Su Hija-JmbVReAfEZo.es-419.vtt',
#  '„Bill Gates hat noch nicht angerufen“-KkPmlYZ_0_g.de.vtt',
#  'Learn English with Bill Gates-uB-d0qCLXfA.en.vtt',
#  'Bill Gates - Top 10 Real Facts-TZ3tn2TTc1U.en.vtt',
#  'Bill Gates - A conversation on poverty and prosperity _ LIVE STREAM-qYS9lOpNWTo.en.vtt',
#  'ATAKUJĄ NAS CHEMICZNIE - Bill Gates, & The Fabian Społeczność-HT_9r-BgWjI.pl.vtt',
#  'A história de Bill Gates - A História da Microsoft - Histórias de Sucesso #6-MAfYQfRn4iI.pt.vtt',
#  'Living in extreme poverty-efnHiz0USQE.en.vtt',
#  'BILL GATES C-19 AGENDA CHE NESSUNO PARLA DI ...-fTEVZFYxYrU.it.vtt',
#  'Hatriot Mail - Bill Gates Vaccine BAD, Chloroquine GOOD-DDVbCiGUT64.en.vtt',
#  'Henry Kissinger i Bill Gates wzywa do masowych szczepień Globalne zarządzanie-7PPVGpDHH3Y.pl.vtt',
#  'Bill Gates on Software Breakthroughs & Computer Science Education - MIT 2004-ozfGHONpdTA.en.vtt',
#  '10 PERSONNES QUI FERONT PARAITRE BILL GATES PAUVRE _ Lama Faché-si2kkFdg-oc.fr.vtt',
#  'What Does Bill Gates Do On His Day Off-eOD8iGMhKoM.en.vtt',
#  'Bill Gates and the Population Control Grid-igx86PoU7v8.en.vtt',
#  'Does saving more lives lead to overpopulation-obRG-2jurz0.en.vtt',
#  '🔵THE REAL BILL GATES PREDICTIONS FOR 2018 - 2035 REVEALED!!! MUST SEE!!! DONT BE AFRAID!!! 🔵-TpqdERCZrSU.en.vtt',
#  "INSIDE BILL'S BRAIN - Decoding Bill Gates Trailer _ Netflix Original Documentary-mWtcPPoGiBE.en.vtt",
#  'Pentagon Vaccine to Modify Behavior (2005)(Bill Gates)-TZtq-AmdG3M.es.vtt',
#  'Bill Gates Best Motivational And Funny Speech At Harvard University-G5XtrznTom8.en.vtt',
#  "Bill Gates in 1989 On His Hiring Process, Microsoft's Seattle Area Office-7u7MPIDa72s.en.vtt",
#  'Warren Buffett And Bill Gates - The Rich Should Pay Higher Taxes-4JrfTmZbFO0.en.vtt',
#  'Bill Gates la anecdota que le cambió la vida. (CC).-J1aUkkuYhKc.es.vtt',
#  'Bill Gates informa que la criptomoneda es el futuro-fwQ7on9FiVA.en.vtt',
#  'How To BECOME A MILLIONAIRE - Bill Gates-v9QgiwgqNkg.en.vtt',
#  'Bill and Melinda Gates’s 2019 Annual Letter-fGrdCnDypeM.en.vtt',
#  "What Most Schools Don't Teach-nKIu9yen5nc.en.vtt",
#  'Bill Gates Humse COVID-19 Ke Bare Mein Kya Chupa Raha Hai (Conspiracy Theory) _ What is World-WneFD14II2I.en.vtt',
#  'Bill Gates - Paranın Bozamadığı Dahi-QQ2V6D4M0w4.en.vtt',
#  'Bill Gates - Visions of the Future _ Big History Project-oxbSM2IwIBo.en.vtt',
#  "Bill Gates - 'Trump is open-minded'-Fy7TEfoiOWU.en-GB.vtt",
#  'Bill Gates - Pandemie Nr. 2 - Bioterrorismus - Deutsche Untertitel-FjcS6upJaRE.de.vtt',
#  'What Gates Said When Trump Asked Him To Be His Science Advisor In 2018-m0krtoKb8GU.en.vtt',
#  'Bill Gates’s Heroes in the Field - Dr. Peter Piot-Zm8zDD717DY.en.vtt',
#  'Bill Gates créateur du Covid  - Désintox - ARTE-Y6OQ15nzoFc.fr.vtt',
#  'Elon Musk and Bill Gates team up to cure for erectile dysfunction - Best Jokes Reddit Vol.15-XNbEttp6VSI.en-US.vtt',
#  'Seria BILL GATES um EUGENISTA-oXhUl4jhiGU.pt-BR.vtt',
#  'Doctor - Bill Gates donation could have huge impact on research-bIuhCUxpPsQ.en.vtt',
#  "Here's How Much Money Bill Gates Makes In A Day-De8DKyGVpz0.en.vtt",
#  "OpenAI and Shocking AI Salaries, Bill Gates' $2b Clean Energy Fund, Playing POTUS with Fiscal Ship-mz5gHOFVmdE.en.vtt",
#  'The Best Teacher I Never Had-WOoJh6oYAXE.en.vtt',
#  'CHANGE OF MIND - I LOVE BILL GATES AND VACCINES, BILL GATES IS A HERO!-bKU8qKzaK_8.en.vtt',
#  'Bill Gates – mehr Schein als Sein _ 28. August 2017 _ www.kla.tv_10988-UdDAmrG0_BM.de.vtt',
#  'The HighWire - Over Ferguson en Bill Gates--W7ZfpHbWZM.nl.vtt',
#  'Elton John and Bill Gates encourage the world to fight HIV-fqG-l8mvDJY.en.vtt',
#  "Bill Gates BBC Wywiad Szczepionka dla 7 miliardów ludzi powoduje oburzenie u Roberta Kennedy'ego-PeTOkUr1aaY.pl.vtt",
#  'Does Bill Gates Pay His Fair Share-Kxde3937KzU.ko.vtt',
#  'La Règle Des 5 Heures (Utilisée par Bill Gates, Elon Musk, Jack Ma…)-yazGrkAYDUQ.fr.vtt',
#  'Bill Gates - The Vaccine Guru with a mission-uVFI7pZzNAY.en.vtt',
#  'Bill Gates, Epstein, Fauci, Birx, CRISPR - WTF-WDUjIcmHBH4.en.vtt',
#  'Bill Gates PREDICTED The Coronavirus In 2015-0flXlWIT2V8.en.vtt',
#  'Lo Que Dijo Bill Gates Cuando Trump Le Pidió Que Fuera Su Asesor Científico-aN_BO4Sez-Q.es.vtt',
#  '50% of Fox Viewers Think Bill Gates Using Pandemic to Microchip Them-O_tF0qAf2sY.en.vtt',
#  'Bill Gates & Steven Pinker Discuss Enlightenment Now-ABVVDSgihYs.en.vtt',
#  'TAHU INDUSTRI ini, Anda adalah BILL GATES BERIKUTNYA ft. Chatib Basri !!! (Part 3 of 3) Hara Token-8CWhXuoDio4.id.vtt',
#  'LA PACE DI VENEZIA, QUANDO BILL GATES ERA DOGE IN CITTÀ - I DOGI DI VENEZIA EP.19-PBx9kcDBdp8.it.vtt',
#  'Entrevista a BILL GATES de MSNBC ¿Que tan rápido se van a conseguir la vacunasSubtitulos en español-4A8JmH1fQOg.es-419.vtt',
#  'Bill Gates Discursa em Harvard - legendado PtBr-WZU6bZfKCDs.en.vtt',
#  'How Warren Buffett Tried To Trick Bill Gates In A Dice Game-oLls20X3AqE.en.vtt',
#  'Is the Bill & Melinda Gates Foundation kicked out of India for reportedly funding the HPV studies-BG8nu4xs3Ck.en.vtt',
#  'Bill Gates Polish srt-OAnLTiBIRts.de.vtt',
#  'COVID-19 - Bill Gates, curfews, and population control through mass vaccinations-6V2O5vAvv38.de.vtt',
#  'Code Break 5.0 - Simulations and Data with Bill Gates-fv5g9xw_jek.en-US.vtt',
#  "'Bill Gates còn kịp lên tổng thống Mỹ' _ Tin Tức 24h-FyAUyEX4WE8.vi.vtt",
#  "Why Saudi's Crown Prince Just Met With Trump, Oprah, Bill Gates, and Jeff Bezos-r9r4c1d8kSw.en.vtt",
#  "Bill Gates - Who's Bill Gates , Background of Bill Gates, ប្រវត្តិរូបលោកប៊ិល ហ្គេត-k-gRgaAgTyw.en.vtt",
#  'Code Break 5 0  Simulations and Data with Bill Gates   Part 2   Interpreted-cKNkkRBZ5wg.en-US.vtt',
#  'Mambo 10 Usiyofahamu kuhusu BILL GATES 🤑🤑-Y6jsGz-Ga3A.en.vtt',
#  'Innovating to zero! _ Bill Gates-JaF-fq2Zn7I.en.vtt',
#  'PARLAMENTO - SARA CUNIAL TRASCINA BILL GATES, SOROS E TUTTI GLI ALTRI ALLA SBARRA.-mZ32rLrL2ag.es.vtt',
#  'Have ENERGY - Bill Gates (@BillGates) - #Entspresso-W5jg1lUHVs0.en.vtt',
#  'Bill Gates, le jeune PROGRAMMEUR. TeaTime!-NuC4QVe_r8M.fr.vtt',
#  "Bill Gates' Commencement Speech at HARVARD 2007 with ENGLISH SUBTITLES-s5gIdRQMr5o.en.vtt",
#  'Bill Gates explains the Common Core-QyM5iTETP6w.en.vtt',
#  'Gates Plan - தனி ஒருவன் _ Jallikattu To Lockdown _ Thanioruvan _ Tamil Pokkisham _ Vicky _ TP-96n9oIke_pY.en-GB.vtt',
#  'MARK OF THE BEAST - Bill Gates, Fauci, Vaccines, ID2020 (666 MARK OF THE BEAST HERE) Underground 134-s9CHC1gRNIA.ar.vtt',
#  'Bill Gates Explainer - A Mind-Blowing Fact-qtm9B9Ww9RA.en.vtt',
#  "Chairman Bill Gates' Coffee Habit-XJn_4cPT6nE.en.vtt",
#  'Henry Kissinger & Bill Gates roepen op tot massavaccinatie en wereldbestuur-Cwm3Q6ic6wU.nl.vtt',
#  'How Rich Is Bill Gates _ The Real Net Worth-6N4Tj5yiNlA.en.vtt',
#  'WHAT MAKES BILL GATES SO SUCCESSFUL 7 Highly Effective Habits-IqLpMCG5y94.es-US.vtt',
#  'Bill Gates - Is the World Getting Better #GOALKEEPERS17-S3DOI3SNBt0.en.vtt',
#  'Bill Gates and Ed Yong Talk About Microbes-HME44N9J8Iw.en.vtt',
#  'Palmistry Bill Gates Money Lines  _ Richest Man World _ Huge Wealth  Palm Hand Reading-cqrAZmmoAD4.en.vtt',
#  'Bill Gates & the Power of Human Capital-Sarah Abushaar بيل غيتس وقوة التنمية البشرية - سارة أبو شعر-fMuAcFFVPMo.ar.vtt',
#  'Steve Jobs Funniest Joke. Even Bill Gates Laughs!-Qv1pvRDFFqs.en.vtt',
#  'Why Did Bill Gates Donate $1M to Gun Control-eZ7VBivGHIk.en.vtt',
#  'BILL GATES, HIS VACCINES, NEW WORLD ORDER AGENDA, CONSPIRACY THEORY OF CORONA VIRUS! THE APOCALYPSE.-t56-L_JoOgQ.en-GB.vtt',
#  'Who was Bill Gates Before Microsoft-gT009dDwIMw.pl.vtt',
#  'বিল গ্রেটস এর সফলতার কাহিনী  Bill Gates Life History  Success Story of Microsoft  habit for success-6RHwYAccNRo.bn.vtt',
#  'JASON HICKEL on NGOs and Bill Gates-ePQ1u8RCncQ.en-GB.vtt',
#  'AwakenWithJP Believes Too Much Media _ WHO _ Bill Gates-86-KdJcwPUA.en.vtt',
#  'Bill Gates loses at chess - Magnus Carlsen beats Gates in 71 seconds-QFlAE99Zz38.en-GB.vtt',
#  'Bill Gates Had A Blast While Filming Latest Episode Of The Big Bang Theory-enLg2A1vR4o.en.vtt',
#  "Bill Gates's 10 RULES for SUCCESS-uS6WBQRU07g.en-US.vtt",
#  'Trending - Woman Gets a Secret Santa Gift From Bill Gates-4XVzSTN4Cv8.en.vtt',
#  'RICARDO CLAURE (BILL GATES 3 EL GOBERNANTE MUNDIAL CONFORME A LA PROFECÍA BÍBLICA)-FrYcq1xfDjU.es-ES.vtt',
#  "Dr. Deborah Birx, what is the Bill Gates's role in advising U.S. government regarding coronavirus -PRqHlo12YZc.en.vtt",
#  'Bill Gates - I worry about US-China relations-fGYz5SszZ74.en.vtt',
#  'Why Bill Gates Is Funding Solar Geoengineering Research-WR6uSXW-8p4.en.vtt',
#  'Relojes de CEOs y Ejecutivos de Negocios Famosos Parte II (Bill Gates, Warren Buffett y más)-TFpNbsXL0Q8.es-MX.vtt',
#  "Bill Gates Donates $100M To Alzheimer's Research-1flAXazmmxc.en.vtt",
#  'Stanford HAI 2019 - A Conversation with Bill Gates-linueXhJ5ZE.en-US.vtt',
#  'Experiência de Bill Gates TED Connects SOCIALMENTE CONECTADOS COVID-19 c_ leg em Port. 4_4-q97NKntTAGs.pt-BR.vtt',
#  'Bill Gates slams wind and solar energy-ug1pb8rkI0s.cs.vtt',
#  'SPOTLIGHT #1 _ Das falsche Bild des Bill Gates _ UNITE & RISE-XTBUm53Ypac.de-DE.vtt',
#  'Melinda Gates On Pandemic - ‘We Haven’t Had Leadership At The National Level … It’s Chaos’ _ TODAY-DEDqsEjhQYk.en.vtt',
#  'Snoop Dogg vs. Xbox & Bill Gates (Rap Version _ Beat)-Kfdvg9KPwcA.en.vtt',
#  'Bill Gates on role US should play in global poverty fight-kirNdaJ8R6Y.en.vtt',
#  'LA ESCALOFRIANTE PROFECIA BILL  GATES DE  HISTORIA-nCkmdsNcO-g.en.vtt',
#  'Bize Yalan Söylediler - Bekçi Maaşları, İdlib, Manyetik Kutup, Bill Gates (20. Bölüm)-cSPlsSZk-e4.tr.vtt',
#  'Bill Gates on Innovation-p8PsR0a1FlI.en.vtt',
#  'TOP 5 CASE STUDIES from BILL GATES favourite book _ SeeKen-6dk0fo9hQzs.en-GB.vtt',
#  "Bill Gates - 'What could cause, in a single year, an excess of 10 million deaths'-5ToWY_BYb00.en.vtt",
#  'Bill Gates stepping down from Microsoft, Berkshire Hathaway boards-4fCxUbbdsBs.fr.vtt',
#  'Bill Gates explains how vaccines work-hh6xTguRn9o.en.vtt',
#  'Bill Gates - ¿La próxima epidemia No estamos listos _ premonición o aviso-9v9UNQtrvKk.es-ES.vtt',
#  'Gates & WHO - Wie die Weltgesundheit zum Unternehmen wird-QtNn2BE_6rE.de.vtt',
#  'Bill Gates on Factfulness-5uooRe07mYM.en.vtt',
#  'Epic Rap Battles Of History - Bill Gates vs Steve Jobs (HQ Audio)-Oq2fhLFUiAA.en-US.vtt',
#  'Secret Santa surprise - Bill Gates sends 81 pound gift to Waterford woman-iaq-91-Ac-w.en.vtt',
#  'Bill Gates and Warren Buffett pick up a shift at Dairy Queen-NQWkNXr2ujI.en.vtt',
#  "Covid-19  VACCINE BILL GATES  Hydrogel MARK of The BEAST OBAMA J.LO MOCKERY- WHERE'S THE URGENCY!!!-Sp1v1grgaR4.en.vtt",
#  'Robert F. Kennedy jr. - „Bill Gates’ globalistisch-diktatorische Impf-Agenda“ _ 22.04.2020 _ kla.tv-gYIpxGJwqEA.de.vtt',
#  'Bill Gates chce zabić (prawie) wszystkie komary-LV_BdSKSFyo.pl.vtt',
#  'VERIFY - Bill Gates and microchipping-1-n3HLUJEGE.en.vtt',
#  'A Conversation with the 2017 Washington State Teacher of the Year-8Ygy1VpV3KA.en.vtt',
#  'Bill Gates Compra Iate Movido Hidrogênio Por R$2,456,664,000 Bilhões-H6piv8STOnk.en.vtt',
#  '5 books worth reading this summer-pwGbwYAfSmg.en.vtt',
#  'bill gates protes pemerintah...!!! Amerika kalah dengan asia cara atasi CORONA-ZpbHJs1JHV8.en.vtt',
#  'Jangan Contoh Bill Gates!-UyZeDjp3D5c.en.vtt',
#  'Bill Gates’s Heroes in the Field - Mandy Manning-WOtu1S6xiAo.en.vtt',
#  '7 frases de BILL GATES para MUDAR SUA VIDA!-4Lh6D9r0u4g.pt-BR.vtt',
#  'Who is the most enlightened leader Bill Gates, Jeff Bezos, Jack Ma, Steve Jobs, Elon Musk-2FjlxNySaHE.de.vtt',
#  'Meet Bill Gates-DSvhPnUgyz8.en.vtt',
#  'Bill Gates & Warren Buffett - DO IT RIGHT NOW ~ A LIFE CHANGING MOTIVATIONAL VIDEO [MUST WATCH]-nJec6SUP_iM.en.vtt',
#  'Limbitless Solutions - Bill Gates  _ Video Breakdown _ Ep. 9-J8YfcSuWmic.en.vtt',
#  'Entrevista a Bill Gates por Trevor Noah  subtitulos español desde THE DAILY SOCIAL DISTANCING SHOW-lA8Ls_gH_Zc.es-419.vtt',
#  "Bill Gates pour L'ÉCHAPPÉE VOLÉE-qWabf0aMjes.fr.vtt",
#  'Bill Gates already warned about the Corona virus.-Q0Kao8nz6-A.en.vtt',
#  'Bill Gates - We Could See Early Results From Coronavirus Vaccine Trials This Summer-ipaP5zTVKKU.en.vtt',
#  'Bill Gates Wants to Reinvent the Toilet _ The Daily Show-v5pW_Mqt6dU.en.vtt',
#  "Bill Gates calls Steve Jobs a 'wizard' who saved Apple-ZeKSDy15q-I.en.vtt",
#  'Shut down the country NOW _ Bill Gates 2020 Prediction-paKMDpfDuug.en.vtt',
#  'Bill Gates and John Green Discuss Progress-uMLy-SCa0zc.en.vtt',
#  'Bill Gates v televízii ARD - Chcem zaočkovať 7 miliárd ľudí !!!-4VyBlJ3NQf0.sk.vtt',
#  'Milyarder Bill Gates bakkal fiyatları tahmin ediyor. Ellen show (Türkçe Altyazılı)-tKX8e7QaTNg.tr.vtt',
#  'Bill Gates - Sus 10 Reglas del Éxito (Subtitulado)-AM4-oOJBLXE.es.vtt',
#  'Comment developper son Business (Conseils de Bill Gates)-jifeCiOkN4g.fr.vtt',
#  'Testing Mattresses with Warren Buffett-6XFwlNVRD5M.en.vtt',
#  'Sara Cunial   Deep State, Bill Gates, Agenda 21 in der Abgeordnetenkammer 14  Mai 2020-BWyTeZlx55w.es-419.vtt',
#  'Alan Keyes - Bill Gates Is Trying To Kill You! (With Vaccines)-2ckxh5RT0Gk.en.vtt',
#  "Netflix Tung Trailer Phim 'Bộ não của Bill - Giải mã Bill Gates' _ Tony Xin Chào-iKY4zhkwUnA.vi.vtt",
#  'Time Management Tips By Bill Gates - 5 Productivity Tips-h_oSEqDXYkI.en.vtt',
#  'A conversation with Bill Gates and Francis Collins on global health and genomics at #ASHG17-hUylrQ35114.en.vtt',
#  'Sarah Abushaar on the Bill Gates Address - SkyNews مقابلة مع سارة أبو شعر عن كلمة الترحيب ببيل غيتس-AKObKLjtJEk.en.vtt',
#  'Heroes in the Field - Dr. Bill Foege-qgZwroXzar8.en.vtt',
#  'Chip-Implantate - Netzgeschichten-PWtdkq48P08.de.vtt',
#  "Bill Gates'in Gerçekleşen Kehanetleri(Büyük Kahin!)-dDlH20l6rXY.en.vtt",
#  'Bill Gates and John Green Discuss Agriculture-3vUgedVu0NA.en.vtt',
#  'Bill Gates Predicted This Back In 2015 But No One Listened - You Need To See This-dLMfhdLF6jQ.en.vtt',
#  'How to make concrete green-0pAH-6R5J2A.en.vtt',
#  'Wie steuert der GP – Bill Gates und das Coronavirus. (Valeriy Pyakin 2020.04.20)-mOoK8sFyTgY.de.vtt',
#  'Il CoronaVirus, Bill Gates, il 5G. Discutiamo complotti e fake news. E ne scopriamo di nuove...-ZNYH1gnAwVY.it.vtt',
#  'Bill Gates’s Heroes in the Field - Dr. Raj Panjabi-c79B3gyf3xY.en.vtt',
#  '¡LOS PLANES DE BILL GATES HAN SIDO EXPUESTOS!-Q2VPN8Yr1BU.es.vtt',
#  'BILL GATES - Mini biographie-1rlp6bAZLtU.fr.vtt',
#  'Celebs Who Insulted Ellen On Her Show-5urZ9rrUVGM.en.vtt',
#  'Beating Nature at Its Own Game-ae8CLc3wXYs.en.vtt',
#  'Bill Gates On How Quickly We Could See A Coronavirus Vaccine _ MSNBC-TySmb2_kZj0.en.vtt',
#  'Tough questions with Bill & Melinda Gates-fxTbAzlbkNs.en.vtt',
#  'Coronavirus und Bill Gates - Die unbeantworteten Fragen _ 07. März 2020 _ www.kla.tv_15831-uOP9527y7h0.de.vtt',
#  'The race for a COVID-19 vaccine, explained-u1AQ5EXcJYc.en.vtt',
#  'BILL GATES UDAH TAU BAKAL ADA COVID 19 _ CORONA, SEJAK 5 TAHUN LALU.-csozbIUq3wY.id.vtt',
#  'Qui était Bill Gates avant Microsoft  (sous titres français)-gmhbeb0dVFA.fr.vtt',
#  'Leonardo da Vinci-oOUjIcH67y8.en.vtt',
#  'Bill Gates Buys Home Near University Of Chicago-xvUhs51KXQk.en.vtt',
#  'Warren Buffet and Bill Gates on Business, Success & Technology-9aIuezOsYpE.en.vtt',
#  'BILL GATES QUIERE REDUCIR LA POBLACION MUNDIAL CON EL VIRUS-07HNYmIAuwE.en.vtt',
#  'Ingraham - Civil liberties at risk in COVID-19 era-wF3-4SkaSt4.en.vtt',
#  'Top 7 Windows Features To Enable! (or Bill Gates will come to your home and knock you unconscious)-fYbbNiDDtkU.en.vtt',
#  'Who was Bill Gates Before Microsoft-2wuMkShZ42o.en.vtt',
#  '¡LAS PREDICCIONES DE BILL GATES PARA 2018 - 2035 REVELADAS! ¡¡¡DEBES VER!!! ¡NO TENGAS MIEDO!-q7KJu514LcU.es-US.vtt',
#  'Partie 1 - Comment Bill Gates monopolise la santé mondiale-BX1_2j-QQuk.fr.vtt',
#  'The next outbreak We’re not ready _ Bill Gates-6Af6b_wyiwI.en.vtt',
#  'Bill Gates o knize Faktomluva (Factfulness) Hanse Roslinga-H7D6y3QqQeY.cs.vtt',
#  'Frontiers of Science with Bill Gates  #GOALKEEPERS17-hVw1VKt9XAw.en.vtt',
#  '9 SURPRISING FACTS About Bill Gates - #DidYouKnow-Fixemj2QoDw.en.vtt',
#  'Bill Gates About Viral Infection _ Bill Gates Decided To Make Viral Infection Vaccine-dj7Mrk9PL-g.ur.vtt',
#  "Did Bill Gates know we'll face to a pandemic virus -wUtLKJUxBPA.en-US.vtt",
#  'Bill Gates Admits It Was a Mistake Meeting with Jeffrey Epstein-iEVXaTP34hE.en.vtt',
#  'What Bill Gates is afraid of-9AEMKudv5p0.en.vtt',
#  'Bill Gates’s Heroes in the Field - Dr. Andreas Diacon-9M84sJCUuO8.en.vtt',
#  'Putting Students First-Rh20W2uXHCc.en.vtt',
#  'E38 - BILL GATES TIENE LA PATENTE - CORONAVIRUS-XpRiHXquN1o.zh-Hans.vtt',
#  'Bill Gates under investigation-Ff5poj37iFc.en.vtt',
#  'Steve Jobs vs Bill Gates. Epic Rap Battles of History-njos57IJf-0.en.vtt',
#  'Teori Konspirasi Covid-19, Bill Gates dan Elite Global Merencanakan Semua-zrQaEybc4u4.id.vtt',
#  'Cómo es el impresionante yate de lujo ecológico que Bill Gates compró por 645 millones de dólares.-GXYBr668ixo.es.vtt',
#  'Shocking Speech about Bill Gates by Sara Cunial, deepstate, agenda21, ENGLISH SUBTITLES-CAVEkWUOaIE.en.vtt',
#  'News Wrap - Manafort and Gates will stay under house arrest for now, judge rules-K9Ef8HErwOo.en.vtt',
#  "Bill Gates' Advice for Young People Who Want to Be Rich-p0pgrq-DXCY.en.vtt",
#  "Bill Gates (motivation) from inside Bill's brain -Decoding Bill gates،بيل غيتس,видео мотивации-wwI0MhWSDpQ.ar.vtt",
#  'Wie Bill Gates das Weltgesundheitssystem monopolisiert - dt. untertitelt-QVYj1HQyPg0.de.vtt',
#  'Bill Gates Wants to Save the World-Gnh4GBzgPHM.en.vtt',
#  'Bill Gates on the global effort to fight disease-cPhEs0W0q6c.en.vtt',
#  'Bill Gates vrea despăgubiri-ZmKP50vpAXc.ro.vtt',
#  'Bill Gates vs Earth - un filantropo samaritano o forse no-8-etktBzFos.it.vtt',
#  "Bill Gates' message to Simon Groot (2019 World Food Prize Laureate)-1Qe-aVKboXU.en.vtt",
#  'Bill Gates’s Heroes in the Field - Mechai Viravaidya-MZ42XmzAzJQ.en.vtt',
#  'Billionaire Bill Gates Guesses Grocery Store Prices-ad_higXixRA.en.vtt',
#  "Bill Gates Wasn't Worried About Burnout In 1984 – Here's Why-MhnSzwXvGfc.en.vtt",
#  'George Osborne and Bill Gates join forces to fight malaria-z8imouImljY.en.vtt',
#  'My conversation with Jared Diamond-AVOyrj48MIM.en.vtt',
#  "William H. Gates III COL '77, LLD '07 Q&A _ The Harvard Campaign Launch-cBHJ-8Bch4E.en.vtt",
#  '5 books to enjoy this winter-AFKktZURpJ8.en.vtt',
#  'Melinda Gates on Raising Ambitious and Altruistic Children _ SuperSoul Sunday _ OWN-q8N_jQR712Q.en.vtt',
#  'Est-ce-que Bill Gates profite du covid19 -i0ximl5ynZ8.fr.vtt',
#  "Bill Gates's Top 10 Rules For Success - Volume 2 (@BillGates)-ksnl2bZWoQI.en.vtt",
#  'Hour of Code - Bill Gates explains If statements-m2Ux2PnJe6E.en.vtt',
#  'Bill Gates ruft zu einem landesweiten Notstand der USA!!! 30.03.2020.  MIT UNTERTITEL!-1BEjH0TCnCc.de.vtt',
#  'La insólita condición que la mujer de Bill Gates tuvo que aceptar antes de casarse-N-GYUrNYhsA.es.vtt',
#  'Bill Gates talks about the Khan Academy at Aspen Ideas Festival 2010-6A07Pj71TUA.en.vtt',
#  'Bill Gates Real Story  _ Biography Of Bill Gates InTelugu _ Bill Gates History-5oozdeT2i9k.en-GB.vtt',
#  'Will Bill Gates Microchip Us With COVID 19 Vaccine-hXR2KKyQt0Q.en.vtt',
#  'Bill Gates and His Wild Side!-B42kKgw5sJQ.en.vtt',
#  'Bill Gates and Warren Buffett are in East Tennessee-SCuieIYNY6c.en.vtt',
#  "Bill Gates's Heroes in the Field - Dr. Kopano Matlwa Mabaso-JBRn1LfRdYk.en.vtt",
#  'Bill Gates Talks About Warren Buffett’s Annual Letter-RVGVjk1amWE.en.vtt',
#  'Nobody Likes Mosquitoes-ot5EH_qQSGg.en.vtt',
#  'Bill Gates Steps Down From Microsoft Board-i9Rr-8cIMuY.en.vtt',
#  "Bill Gates says Trump's decision to halt WHO funding is 'as dangerous as it sounds'-r3WoAW-ZTpk.en.vtt",
#  'Teori Konspirasi Bill Gates & Corona _ Benarkah Bill Gates Di Balik Covid-19-xYZgeMlt5qs.en.vtt',
#  'Bill Gates’s Heroes in the Field - Drs. Samir and Senjuti Saha-BnDFm73IDVA.en.vtt',
#  'Bill Gates - Corona Virus Interview on BBC (Translated in Many Languages)--7ZJb38ADug.en.vtt',
#  'Jeff Bezos Briefly Overtakes Bill Gates As World’s Richest Person _ TODAY-klab1ziIl0o.en.vtt',
#  "Commend your leadership' - Bill Gates lauds Modi govt's efforts to flatten Covid curve-_F0qC7I-Pq4.en-US.vtt",
#  'Bill Gates Harvard Commencement Address 2007-zPx5N6Lh3sw.en.vtt',
#  "Lunatic Trumpists Will REFUSE 'Bill Gates Vaccine'-LaAPJdO3dgA.en.vtt",
#  'Experiência de Bill Gates TED Connects BOA PERSPECTIVA P_ PRÓX. VÍRUS COVID-19 c_ leg em Port 3_4-UaltIfBz6DY.pt-BR.vtt',
#  'Hanya WHO bisa selamatkan dunia... Bill gates kutuk donald trump-hk4DbVywhxw.en.vtt',
#  'Revelation - Bill Gates & ID2020 _ Microchips for a Cashless Society - NL Ondertiteling-tBNNPdyMshE.en.vtt',
#  'What Do Mozart, Bill Gates and The Beatles All Have in Common-rZdiH9VKq70.en.vtt',
#  'How Bill Gates Monopolized Global Health-wQSYdAX_9JY.en.vtt',
#  'Bill & Melinda Gates Foundation under fire over awarding India’s Prime Minister-ogMEpsGh9Yo.en.vtt',
#  'Water Street Tampa - $3 Billion Future City Make Over with Coverage of Dreamit Accelerator-wbBzjEa477A.en.vtt',
#  "Bill Gates' Plan to Vaccinate the World-VQSM7EVCFbY.ro.vtt",
#  'Bill Gates Cảnh Báo Về Dịch Bệnh X - Hàng Triệu Người Sẽ Mắc Phải _ Tony Xin Chào-PoHAp1-3_bU.vi.vtt',
#  'Bill Gates Green Technology-ITuw1a-i_Qs.en.vtt',
#  'Dead Wrong® with Johan Norberg - How Much Richer is Bill Gates-zmtxU8q6ohA.en.vtt',
#  'BILL GATES Và Những Sự Thật Ngạc Nhiên Về Vị Tỉ Phú Giàu Có Của Thế Giới - Tốp 5 Lạ Kỳ 🔥🔥🔥-IpfRyZQ2UXI.vi.vtt',
#  'Bill Gates Speaks Out About His $100 Million Mission To Cure Alzheimer’s _ TODAY-pb5XxvM5Si0.en.vtt',
#  'Questions à Bill Gates _ Lutte contre le SIDA, la tuberculose et le paludisme-u6IvHpD132Y.en.vtt',
#  'Bill Gates will die Welt impfen-AhuU_CG9v80.de.vtt',
#  'MISA - BILL GATES-uQF6wCljTOA.fr.vtt',
#  'Biohackers Are on a Secret Hunt for the Coronavirus Vaccine-7BTvVnOgc10.en.vtt',
#  'Investment in Africa needed to keep extreme poverty on the wane, Bill and Melinda Gates say-Twr93kytMaI.en.vtt',
#  'Bill Gates speaks on what India does right-_jxhZIZIINg.en.vtt',
#  'Bill Gates talks toilets-82pmo53FQIY.en.vtt',
#  'Thorsten Schulte - Bill Gates Menschenfreund oder Menschenfeind _ 12.05.2020 _ www.kla.tv_16378-I96Q4znsULs.de.vtt',
#  'How to make BBQ chicken with Bill Gates-g-G48emmWto.en.vtt',
#  'Bill Gates prevede la fase 2 - Un attacco BioTerroristico-v0UdgSEs6LI.it.vtt',
#  "'Code Stars' - Short Film-dU1xS07N-FA.en.vtt",
#  'Bill Gates on Fighting Coronavirus _ The Daily Social Distancing Show-iyFT8qXcOrM.en-US.vtt',
#  'How state budgets are breaking US schools _ Bill Gates-jiUKpX09zo4.en.vtt',
#  'Bill Gates Stiftung - Die Kritik im Faktencheck!-NtdnddEXWlE.de-DE.vtt',
#  '5 summer book recommendations-4R8CB0QqTA8.en.vtt',
#  'Introducing How Computers Work-OAx_6-wdslM.en.vtt',
#  'Summer Reading 2017 by Bill Gates-MNfsLMDcGZ8.en.vtt',
#  'Bill Gates explains how the United States can safely ease coronavirus restrictions-pb_nKwumwNA.en.vtt',
#  "EL PARAISO VERDE DUO BESIEGT CORONA VIRUS     BILL GATES 'gates' schlecht-b7Ok9ZGEAcE.de.vtt",
#  'What Bill Gates hopes we learn from coronavirus-jLbJayQygzw.en.vtt',
#  'Frisch geimpft - Leben mit dem Bill-Gates-Chip-YEbQgKIXWVc.en.vtt',
#  'Bill Gates on who should use your data-tQhOtHJWo8A.en.vtt',
#  'Deep State, Bill Gates, Agenda21 alla Camera dei Deputati 14 maggio 2020-mX51utvnj9E.en.vtt',
#  'BILL GATES Entrevista Ted  24_03_2020 Sub. español--uaOL_LJ5Nk.es-419.vtt',
#  '12 Seconds of Bill Gates to End COVID19 With GLOBAL VACCINATIONS-I1aZzNlfq4g.en.vtt',
#  "1mi views!!(orig.inglês) 'Como BILL GATES Monopolizou a Saúde Global' (legendaPORT no APP-clique CC)-8KzJ5cH5_tg.pt.vtt",
#  'Drinking Nasty Swamp Water (to save the world)-6qZWMNW7GmE.en.vtt',
#  'Bill Gates Family With Parents, Wife, Son and Daughters Photos-G2Ano6kl0a8.en.vtt',
#  'Is Bill Gates the richest person in the world _ Fun Facts for Students _ Success Story on Microsoft-5fyMtBmvym8.en.vtt',
#  'First World Problems Vs. Real World Solutions (ft. Bill Gates)-6hcHrGALInA.en.vtt',
#  '☣  - Bill Gates predicted a giant disease that would kill millions of people ⚠ 😱 ☣-nfY9k0RCnMc.en.vtt',
#  'Bill Gates on where the COVID-19 pandemic will hurt the most-W3qz9-bxljA.en-US.vtt',
#  'The evidence for optimism-qhNoFeymyS8.en.vtt',
#  'Bill Gates Thinks These Toilets Could Change The World-_uvzKzWpRNI.en.vtt',
#  'Lord Speaker Lecture - Bill Gates _ House of Lords-ZE5JwqSzHjs.en-GB.vtt',
#  'Awam News بل گیٹس کی گرفتاری کا مطالبہ Bill Gates, Sara Coniel, Breaking News Global News Updates-ETAnfJiAeq8.en.vtt',
#  'Bill Gates typical work day-8QQwcmJyO8E.en.vtt',
#  "Nathan For You - Extended Scene - 'The Web' - Bill Gates's Lament-f8QruYW6v6E.en.vtt",
#  'Sanitation showcase-wqcknE_Ic_g.en.vtt',
#  'David Goggins - This Mindset Makes Bill Gates Successful-ZgnWi2-bCjo.en.vtt',
#  'Bill Gates, Mike Dertouzos - World Economic Forum 1997-KcUaEQFDzq8.en.vtt',
#  'Why Bill Gates is optimistic about the world-tmk0VpSwUcs.en.vtt',
#  'Bill Gates - A próxima epidemia Não estamos preparados.-LCwW_o2ufxM.pt-BR.vtt',
#  'Bill Gates Guest Stars On ‘Big Bang Theory’-nNA22Re3h3A.en.vtt',
#  'Who is Bill Gates Top Greatest Achievements,Software, Microsoft.One of the Richest Men in the world-djdeRq2wgY0.fr.vtt',
#  'Bill Gates explains IF & IF_ELSE statements-fVUL-vzrIcM.en.vtt',
#  '5 books Bill Gates loved in 2018-VldJrHVNHF8.en.vtt',
#  '🆘 APOCALYPSE ✝️ Bill Gates ID2020 And The Mark Of The Beast, Explained By An Anonymous 💉 Covid-19 ☣️-zD4UR51v0fI.en.vtt',
#  'Bill Gates - Corbett Report-5xWX5B7h5k8.en-GB.vtt',
#  'The grand challenges of climate change-0__6kx-vTO4.en.vtt',
#  'Mosquitos, malaria and education _ Bill Gates-tsgvhP07BC8.en.vtt',
#  'Bill Gates Leadership Style - Millionaire SUCCESS ADVICE Series-JzGHR_PMs1c.en.vtt',
#  'Talking Coronavirus with Medical Professionals & Politicians _ The Daily Social Distancing Show-2tawD4qXVgg.en-US.vtt',
#  'NYT - Bill Gates Repeatedly Met With Jeffrey Epstein _ Velshi & Ruhle _ MSNBC-WnKQ4tzg7ow.en.vtt',
#  'Bill Gates Has Major Sock Appeal _ TMZ TV-EztZFwGcqXQ.en.vtt',
#  'Bill Gates on the impact of AI on the job market-sl5ggAJidVQ.en.vtt',
#  'Engineering Lessons with Bill Gates and Camille Jones-yf3UIllAmVo.en.vtt',
#  'How To Live Like Bill Gates - Morning Routine of Bill Gates-I3HCToFJT60.en.vtt',
#  'Bill Gates Daily Income - Daily Income Of Bill Gates - Bill Gates Daily Income In Indian Rupees-4kG6_4xwrUA.en.vtt',
#  'Star Wars & Civil Rights with Bill Gates and Nate Bowling-JSI1yntA7ZI.en.vtt',
#  "BİLL GATES'İN İTİRAFLARI! #ArslanBulut-X9vXmR3B9Uw.tr.vtt",
#  'G2Voice Broadcast #185 – Bill Gates of Hell is at it again-CQrNQOkalnI.en-US.vtt',
#  'Become As Rich As Mark Zuckerberg or Bill Gates-Hq6Y8mVSlsc.en.vtt',
#  'Shortcut To Wealth & Fame - Meditate On Bill Gates & Oprah Winfrey - Lesson 5-5PTOp743T3w.en.vtt',
#  'Bill Gates - Wrangling Cows in the Outback-MG5dQAJcCoM.en.vtt',
#  'Bill Gates on the need for climate innovators-7A4npk1Deug.en.vtt',
#  '5 Things Bill Gates Says You Must Do To Be Successful _ Inc.-cm8pgby3tao.en.vtt',
#  'What did Bill Gates say (WARNING this might get deleted)-j0femV6YGlM.en.vtt',
#  'Deep State, Bill Gates, Agenda21 alla Camera dei Deputati 14 maggio 2020-kUuGqxUzPKY.en.vtt',
#  'COVID-19 - Paty Navidad le echa la culpa a Bill Gates _ Suelta La Sopa-uP3JdoDYvlk.es-MX.vtt',
#  'Bill Gates - Clean energy is the future-8Dll3oyw6ow.en.vtt',
#  'Kenyan Bishops Discover Mass Sterilization in Bill Gates Vaccines-SWvcwYsMDew.en.vtt',
#  'No autism in Vietnam before Bill Gates brought his vaccines - Dr Anthony Phan, MD-_dgc1I-64QU.en-GB.vtt',
#  'Tax The Rich! Bill Gates, Warren Buffett Agree-KBPPpvihR4s.en.vtt',
#  'Bill Gates Sr. Argues For Estate Tax-ZQ_jxLKbbDo.en.vtt',
#  "BILL GATES  - L'INCROYABLE ARNAQUE DERRIÈRE SA FONDATION-Dqzt6yAmdDE.en.vtt",
#  'We Can Eradicate Four Diseases by 2030-NVt8CQOo58s.en.vtt',
#  'What Bill Gates learned after meeting with sex workers in India-kw_acqrMSk8.en.vtt',
#  'Steve Jobs and Bill Gates Face Off _ ٍEnglish Subtitle-9ZoUFLVZbME.en.vtt',
#  'Bill Gates quer varrer você deste mundo e paga a Mídia Prostituta para retratá-lo como um santo-6r9-zV98hts.pt-BR.vtt',
#  'Experiência de Bill Gates em TED Connects SOBRE ISOLAMENTO COVID-19 c_ leg em Port. 1_4-ygSnsCdNvJE.pt-BR.vtt',
#  'Bill Gates tells Trump to Ignore Vaccine Concerns-8UHXKiUoMDw.en.vtt',
#  '5 Super Funny Bill Gates Moments (Business Tips) _ Bill Gates History Videos Compiled-l3a22TP5r58.en.vtt',
#  'Corona Virus (COVID-19) discussion with Bill Gates-NDnjXdDxEhk.en.vtt',
#  'Bill Gates - Impfungen zur Bevölkerungsreduktion    ---Chorionic Gonadotrophin (hCG)----MVb8xe00ru0.de.vtt',
#  "Bill Gates' Plan to Vaccinate the World-o7A_cMpKm6w.en.vtt",
#  'Bill & Melinda Gates Talk Taxing The Wealthy-qG3eNG2rO7o.en.vtt',
#  'Prophetic revelation of antichrist  ▒ Bill Gates-5QCUpo5_78Y.en.vtt',
#  'Gates Goes Nuclear-HijJH67uw_Y.en.vtt',
#  'Bill Gates gets super lucky playing cards! _ Netflix-wT4UD1cARKI.en-US.vtt',
#  'COVID-19 - alles Schwindel Neue Weltordnung Bill Gates-PJNfJOdQ_eI.en.vtt',
#  'The Xerox Thieves - Steve Jobs & Bill Gates-pQocN_c2uLI.en.vtt',
#  'Controversial Depopulation Equation_Formula - Bill Gates-Eg7YH-ouDHM.en.vtt',
#  'Harvard Commencement speaker Mark Zuckerberg asks Bill Gates for advice-yqr6yLyuHQA.en.vtt']

# %%
filenames_vtt = [os.fsdecode(file) for file in os.listdir(os.getcwd()) if os.fsdecode(file).endswith(".vtt")]
#Check file names

# %% [markdown]
# #### Converting vtt to csv

# %%
import webvtt
def convert_vtt(filenames):    
    #create an assets folder if one does not yet exist
    if os.path.isdir('{}/assets'.format(os.getcwd())) == False:
        os.makedirs('assets')
    #extract the text and times from the vtt file
    for file in filenames:
        try:
            captions = webvtt.read(file)
            text_time = pd.DataFrame()
            text_time['text'] = [caption.text for caption in captions]
            text_time['start'] = [caption.start for caption in captions]
            text_time['stop'] = [caption.end for caption in captions]
            text_time.to_csv('assets/{}.csv'.format(file[:-4]),index=False) #-4 to remove '.vtt'
        except:
            print('err')
            pass
        #remove files from local drive
        os.remove(file)

# %%
#call the function
convert_vtt(filenames_vtt)
# Out:
# err

# %%
csv_files = [os.fsdecode(file) for file in os.listdir(os.getcwd()+'/assets') if os.fsdecode(file).endswith('.csv')]

# %%
len(csv_files)
# Out:
# 585

# %%
path = 'assets/'
for filename in csv_files:
    os.rename(os.path.join(path, filename), os.path.join(path, filename.replace(' ', '')))
#to verify the results
clean_csv = [os.fsdecode(file) for file in os.listdir(os.getcwd()+'/assets')]
clean_csv[0]
# Out:
# 'BeethovenasBillGates-JoseBowenatTEDxSMU2011-Jl3gnP4uG2o.en.csv'

# %%
#extract the text and videoid
vidText = []
csv_vidid = []

for file in clean_csv:
   df = pd.read_csv(path+file)
   text = " ".join(df.text)
   vidText.append(text)
   csv_vidid.append(file[-18:-7])

# %%
vtxt = pd.DataFrame(vidText)
vID = pd.DataFrame(csv_vidid)
vtxt.join(vID)

# %%
len(set(csv_vidid))
# Out:
# 574

# %%
len(set(vidText))
# Out:
# 572

# %%
vtxt.join(vID)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d691fcf56ee2> in <module>
# ----> 1 vtxt.join(vID)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     572
#     573         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 574                                                      rdata.items, rsuf)
#     575
#     576         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: RangeIndex(start=0, stop=1, step=1)

# %%
vtxt.to_csv('vidTexts.csv', index = False)
vID.to_csv('vidID.csv', index = False)

# %%
vidText[12]
# Out:
# "of of of of this of of of of of of of of house of blues of of\nof a of of of of of of the of an aunt of force and not make the the same as the end of the facts of this as a foundation of Santa has fashioned a variant of that, and he has this have to have come to the forefront ruled no\nplace for common sense to the\nsuns the info as 2020 bodies might dish out which can only mean one thing programme you are watching the Conejo,\nwhich discusses policies social\nissues my name is my de my name is my de chat through the prism of common\nsense my name is my de Charles my name is mine de chacal my name is my name is mine de chacal de Challes de Challes you are de Challes you are we de Challes you are one de Challes you are watch de Challes you are we see take it with us in the de Challes you are watching on to resets de Challes you are watching on\nparle de prison what it all these de Challes you are watching on\nparle de prison oui the crusty old office says you\nknow de Challes you are watching on\nparle de prison oui tu de Challes you are watching on\nparle de prison oui taux if you've been watching the\nschool room before de Challes you are watching on\nparle de prison oui taux oui de Challes you are watching on\nparle de prison oui taux oui ça de Challes you are watching on\nparle de prison oui taux oui de Challes you are watching on\nparle de prison oui taux oui ça parle de prison oui taux oui\nc'est ça prison oui taux oui c'est ça\nWhatsApp prison oui taux oui c'est ça\nwhat are prison oui taux oui c'est ça\nwhat are you prison oui taux oui c'est ça\nwhat prison oui taux oui c'est ça\nwhat are is prison oui taux oui c'est ça\nwhat are is steak prison oui taux oui c'est ça\nwhat are is stick of prison oui taux oui c'est ça\nwhat are is stick of a fait prison oui taux oui c'est ça\nwhat are is stick of prison oui taux oui c'est ça\nwhat are is stick of à faire prison oui taux oui c'est ça\nwhat are is stick of prison oui taux oui c'est ça\nwhat are is stick of Dino we do not provide them know so\nwe know using a Nissan is the\ncause was easier to get on to\nbeat on an information oui taux oui c'est ça what are\nis stick of Dino programme model which network you\naffiliated with the new\npreferred you get taux oui c'est ça what are is\nstick of Dino programme your information, we do hear\nthese sea scouts are those the shows some the\nprism of common sense stick of Dino programme de stick of Dino programme de your programme de your information the siege on as before we do\nthank you for making this\njourney of they'll be lighter\nthe tide more than programme de your information\nquiche au programme de your information\nprison programme de your information\nprison programme de your information\nprison en the siege on us for the first\ntime once again well, programme de your information\nune prison programme de your information\nune prison il fait programme de your information\nune prison il faut programme de your information\nune prison before we programme de your information\nune prison before we do programme de your information\nune prison before we 12 V programme de your information\nune prison before we programme de your information\nune prison before we do une prison before we do you\nthink you for before we do you think you for\nmaking before we do you think you for\nmaking d'espionner think you for making d'espionner\nalors though so fresh from rom is not\nassociated with any political\nparty and we do for French before we do you think you for\nmaking d'espionner think you for making d'espionner\nà la think you for making d'espionner\nà la mort for making d'espionner à la\nmode d'espionner à la mode il faut\nque tu en as d'espionner à la mode il faut\nque tu en as pas we do not, any political agenda d'espionner à la mode il faut\nque tu en as pas de d'espionner à la mode il faut\nque tu en as pas de force d'espionner à la mode il faut\nque tu en as pas de forfait d'espionner à la mode il faut\nque tu en as pas de force d ...

# %%
Gates_Videos.to_csv('GatesVids.csv')

# %%
Gates_Videos = pd.read_csv("GatesVids.csv")

# %%
Gates_Videos = pd.read_csv("idlst.csv")
