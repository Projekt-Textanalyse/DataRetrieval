# %%
import pandas as pd

# %%
data = pd.read_csv('videos.txt', sep=",", header=None)

# %%
mydat= pd.read_csv('idlst.csv', header=None)

# %%
data = data.transpose()

# %%
set(data.loc[:,0]).difference(mydat.loc[:,0])
# Out:
# {'-iZ0d_Ls_YM',
#  '2NFJPuibw2s',
#  '4uyIhfTp5UY',
#  'BC62GDl4i8Y',
#  'CFcAY9HFXNo',
#  'CTOPt-zELEU',
#  'CdomzguiTsQ',
#  'J87_DKe2W_w',
#  'KXDkZtpzuqc',
#  'KuPCwuSI2n8',
#  'N-xIZj621BY',
#  'NngCPmJ1Aq4',
#  'OhbOmy4d8P8',
#  'PDRdngA1Z9c',
#  'SzYoZ6YySwU',
#  'TULk_N_AlXM',
#  'WDFl48SK71s',
#  'WTQH9f9Ka1s',
#  'ZiAf879udKw',
#  'b_As_5PN-r8',
#  'fGpMpV5pJlE',
#  'fLmNBy8NSkg',
#  'iCYSsdVoNG8',
#  'jH2K2hMIN5Q',
#  'jLsKeZlTlGc',
#  'lzlp-jSogLQ',
#  'nyQxaJ1pISs',
#  't9yUUtBuWG8',
#  'tF-CKYTIAIo',
#  'tMpsn6wDS5E',
#  'veRn8DKRhsg',
#  'xpuSiRD0L7I',
#  'zNVI1SEGxo8',
#  'zawZgR9oTds'}

# %%
data
# Out:
#                0
# 0    jLsKeZlTlGc
# 1    DyIH3O0NRsM
# 2    43LiB6Ynmmw
# 3    N-xIZj621BY
# 4    BC62GDl4i8Y
# 5    BX1_2j-QQuk
# 6    QtNn2BE_6rE
# 7    tF-CKYTIAIo
# 8    lz4dDKSizGg
# 9    oXhUl4jhiGU
# 10   KkPmlYZ_0_g
# 11   b_As_5PN-r8
# 12   bRD4BGec0wU
# 13   -iZ0d_Ls_YM
# 14   O_tF0qAf2sY
# 15   07HNYmIAuwE
# 16   id1ryXAgygE
# 17   WDFl48SK71s
# 18   csozbIUq3wY
# 19   jIM5o-GdGKw
# 20   Gnh4GBzgPHM
# 21   uB-d0qCLXfA
# 22   bKU8qKzaK_8
# 23   tBNNPdyMshE
# 24   _dgc1I-64QU
# 25   jLbJayQygzw
# 26   Y6OQ15nzoFc
# 27   U-onOPOIV60
# 28   jvLcWSYGyJ8
# 29   OAnLTiBIRts
# ..           ...
# 509  OtfEwkwCyUo
# 510  p8PsR0a1FlI
# 511  sbWju-Pt4fk
# 512  nKIu9yen5nc
# 513  ZLkbWUNQbgk
# 514  A04oCqcvqxA
# 515  rZdiH9VKq70
# 516  5PTOp743T3w
# 517  njos57IJf-0
# 518  2BOTS9GAjc4
# 519  Jl3gnP4uG2o
# 520  6r9-zV98hts
# 521  KBPPpvihR4s
# 522  jiUKpX09zo4
# 523  3tCUWbhyiig
# 524  UuMTSU9DcqQ
# 525  1GAVXoRF8MI
# 526  _R8bI4ZzSZ8
# 527  ITuw1a-i_Qs
# 528  8rZSkVa9zoE
# ...
