# %%
import os
import xml.etree.ElementTree as ET

# %%
import pandas as pd
import os
import google.oauth2.credentials
import google_auth_oauthlib.flow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow
CLIENT_SECRETS_FILE = "client_secret.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'
def get_authenticated_service():
    flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)
# Remove keyword arguments that are not set
def remove_empty_kwargs(**kwargs):
    good_kwargs = {}
    if kwargs is not None:
        for key, value in kwargs.items():
            if value:
                good_kwargs[key] = value
    return good_kwargs

# %%
client = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=692697523900-m6jnb73lek6udl104gvou0joh8t0771q.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=O2rgDFrfJ5kVY062gbALmtf5oW3yKz&prompt=consent&access_type=offline
# Enter the authorization code: 4/0AEtq3xJseFOZUi2wEx63TZEGh4StR31UgrWxjuRbZDDaHq9cMuUe7Y

# %%
def youtube_keyword(client, **kwargs):    
    kwargs = remove_empty_kwargs(**kwargs)
    response = client.search().list(
        **kwargs
        ).execute()    
    return response

# %%
def youtube_search (criteria,max_res):   
    #create lists and empty dataframe
    titles = []
    videoIds = []
    channelIds = []
    resp_df = pd.DataFrame()
    
    while len(titles) < max_res:
        token = None
        response = youtube_keyword(client,
                        part='id,snippet',
                        maxResults=50,
                        q=criteria,
                        videoCaption='closedCaption',
                        type='video', 
                        #videoDuration='long',
                        #I18nRegion='de',
                        pageToken=token,
                        relevanceLanguage='de',
                        regionCode='de') 
                                         
        for item in response['items']:        
            titles.append(item['snippet']['title'])
            channelIds.append(item['snippet']['channelTitle'])
            videoIds.append(item['id']['videoId'])
        
        token = response['nextPageToken']
        
    resp_df['title'] = titles
    resp_df['channelId'] = channelIds
    resp_df['videoId'] = videoIds
    resp_df['subject'] = criteria
    
    return resp_df

# %%
Gates_Videos = youtube_search('[Impfen+Bill+Gates]',10)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-37-583ea5e231a1> in <module>
# ----> 1 Gates_Videos = youtube_search('[Impfen+Bill+Gates]',10)
#
# <ipython-input-35-9aa01f730821> in youtube_search(criteria, max_res)
#      18                         pageToken=token,
#      19                         relevanceLanguage='de',
# ---> 20                         regionCode='de')
#      21
#      22         for item in response['items']:
#
# <ipython-input-16-df3a6a419a84> in youtube_keyword(client, **kwargs)
#       2     kwargs = remove_empty_kwargs(**kwargs)
#       3     response = client.search().list(
# ----> 4         **kwargs
#       5         ).execute()
#       6     return response
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     905             callback(resp)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
#     908         return self.postproc(resp, content)
#     909
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3
# 977                                                TED  tsgvhP07BC8
# 978                   QS24 - Schweizer Privatfernsehen  neY5UrYKYk0
# 979                                         TEDx Talks  KG9tm2Z4W-Y
# 980                                            extra 3  Hdp_mi_QA3o
# 981                                              Utler  6RRYqN5hbkw
# 982                                            extra 3  8s3hU3YDh3A
# 983                                         Asian Boss  5cYWd0N8nO4
# 984                                       NDR Ratgeber  Flm-dLvIw80
# 985                                   Christian Felber  yrb8gSAw8_M
# 986                                     Lumira HEALING  0uFYpyfYaXQ
# 987                           ZAPP - Das Medienmagazin  GXl6PPr_UmY
# 988                              Il Progetto Risveglio  8-etktBzFos
# 989                                      Truth Seekers  m7qjJDbL0wI
# 990  Bridgecreation Der Podcast der Menschen verbindet  DbYp7lVctR8
# 991                                         WDR Reisen  in2dRwiShWY
# 992                                       NDR Ratgeber  FbGan7vymVQ
# 993                                      wikipedia tts  n4RExRUQYPA
# 994                                     Ajanogha Okoli  t56-L_JoOgQ
# 995                                           Dracul91  KuZkQWVvinw
# 996                                         Zoe Eather  Jp7gtM7zHcU
# 997                                       klagemauerTV  AwyM72ymszw
# 998                                      Mike Ducheine  ZIXznkrltwE
# 999                                     YouTube Movies  TeZB7LGcC48
#
#             subject
# 0    [Impfen+Gates]
# 1    [Impfen+Gates]
# 2    [Impfen+Gates]
# 3    [Impfen+Gates]
# 4    [Impfen+Gates]
# 5    [Impfen+Gates]
# 6    [Impfen+Gates]
# 7    [Impfen+Gates]
# 8    [Impfen+Gates]
# 9    [Impfen+Gates]
# 10   [Impfen+Gates]
# 11   [Impfen+Gates]
# 12   [Impfen+Gates]
# 13   [Impfen+Gates]
# 14   [Impfen+Gates]
# 15   [Impfen+Gates]
# 16   [Impfen+Gates]
# 17   [Impfen+Gates]
# 18   [Impfen+Gates]
# 19   [Impfen+Gates]
# 20   [Impfen+Gates]
# 21   [Impfen+Gates]
# 22   [Impfen+Gates]
# 23   [Impfen+Gates]
# 24   [Impfen+Gates]
# 25   [Impfen+Gates]
# 26   [Impfen+Gates]
# 27   [Impfen+Gates]
# 28   [Impfen+Gates]
# 29   [Impfen+Gates]
# ..              ...
# 970  [Impfen+Gates]
# 971  [Impfen+Gates]
# 972  [Impfen+Gates]
# 973  [Impfen+Gates]
# 974  [Impfen+Gates]
# 975  [Impfen+Gates]
# 976  [Impfen+Gates]
# 977  [Impfen+Gates]
# 978  [Impfen+Gates]
# 979  [Impfen+Gates]
# 980  [Impfen+Gates]
# 981  [Impfen+Gates]
# 982  [Impfen+Gates]
# 983  [Impfen+Gates]
# 984  [Impfen+Gates]
# 985  [Impfen+Gates]
# 986  [Impfen+Gates]
# 987  [Impfen+Gates]
# 988  [Impfen+Gates]
# 989  [Impfen+Gates]
# 990  [Impfen+Gates]
# 991  [Impfen+Gates]
# 992  [Impfen+Gates]
# 993  [Impfen+Gates]
# 994  [Impfen+Gates]
# 995  [Impfen+Gates]
# 996  [Impfen+Gates]
# 997  [Impfen+Gates]
# 998  [Impfen+Gates]
# 999  [Impfen+Gates]
#
# [1000 rows x 4 columns]

# %%
def get_all_ccs(videos):
    base_url = 'https://www.youtube.com/watch?v='
    lang="de"
    for vid in videos:
        url = base_url + vid
        cmd = ["youtube-dl.exe","--skip-download","--write-sub",
               "--sub-lang",lang,url]
        os.system(" ".join(cmd))

# %%
url = 'https://www.youtube.com/watch?v=TeZB7LGcC48'
cmd = ["youtube-dl.exe","--skip-download","--write-sub",url]
os.system(" ".join(cmd))
# Out:
# 1

# %%
get_all_ccs(Gates_Videos.videoId)

# %%
filenames_vtt = [os.fsdecode(file) for file in os.listdir(os.getcwd()) if os.fsdecode(file).endswith(".vtt")]
#Check file names
filenames_vtt
# Out:
# ["'Pandemie'! Eine schwache Saison Grippe!-0uFYpyfYaXQ.de.vtt",
#  'Bill Gates und  Bevölkerungskontrolle-YWjkYM8slFU.de.vtt',
#  'Bill Gates will die Welt impfen-AhuU_CG9v80.de.vtt',
#  'Corona - die krassesten Thesen und Lügen _ STRG_F-3duErFbfFM0.de.vtt',
#  'Coronavirus-Update #26 - Genbasierte Impfstoffe haben Potenzial _ NDR Podcast-lhujYBcgbKo.de.vtt',
#  'Coronavirus-Update #31 - Eine Wiederinfektion bleibt unwahrscheinlich _ NDR Podcast-nD5EtGYU_nY.de.vtt',
#  'Coronavirus-Update #32 - Jetzt mit Hochdruck Forschungsfragen klären _ NDR Podcast-_pP8AfANjHc.de.vtt',
#  'Coronavirus-Update #33 - Herdenimmunität noch lange nicht in Sicht _ NDR Podcast-DSeZYVYd_DU.de.vtt',
#  'Coronavirus-Update #35 - Vielversprechende Impfstudie aus China _ NDR Podcast-0qsxDbSYz0c.de.vtt',
#  'Coronavirus-Update #36 - Die Rolle von Kindern ist nicht geklärt _ NDR Podcast-_N-XK6u7mIQ.de.vtt',
#  'Coronavirus-Update #42 - Bei der Schweinegrippe kam alles anders _ NDR Podcast-FbGan7vymVQ.de.vtt',
#  'Extra 3 Spezial _ 06.05.2020 mit Sarah Kuttner _ extra 3 _ NDR-Hdp_mi_QA3o.de.vtt',
#  'Extra 3 vom 07.05.2020 mit Christian Ehring im Ersten _ extra 3 _ NDR-8s3hU3YDh3A.de.vtt',
#  'Gebärdensprachvideo - AfD-Anträge zu Grund\xadrechten stoßen auf Widerspruch-joqd-Mvpa6E.de.vtt',
#  'Halle (Saale) - Video-Pressekonferenz vom 19. April 2020 zur Corona-Lage – Mit Untertiteln-o0scbzPHFtM.de.vtt',
#  'HIRSCHHAUSEN ZU HAUS vom 18. Mai 2020 _ Eckart von Hirschhausen im Gespräch mit Stephan Pusch-TW2RoAvihOY.de.vtt',
#  'Innovating to zero! _ Bill Gates-JaF-fq2Zn7I.de.vtt',
#  'Mosquitos, malaria and education _ Bill Gates-tsgvhP07BC8.de.vtt',
#  'Online-Bürgersprechstunde mit Ministerpräsident Kretschmer vom 4. Mai 2020-O8iMjdBFY3A.de.vtt',
#  'Poetry Slammer - MATZE B. at TEDxBodensee-KG9tm2Z4W-Y.de.vtt',
#  'Pressebriefing der Sächsischen Staatsregierung – aktueller Stand zum Coronavirus in Sachsen 14.05.20-V0J94vF_rZ4.de.vtt',
#  'Servus TV Talk mit Prof. Dr. Sucharit Bhakdi - Corona-Wahn ohne Ende-xc-e8zaxicQ.de.vtt',
#  'Tamina in Thailand _ WDR Reisen-in2dRwiShWY.de.vtt',
#  'Visite _ 21.4.2020 _ Visite _ NDR-Flm-dLvIw80.de.vtt',
#  'Von Corona zum Gemeinwohl - Folge 4 - Artenvielfalt, Corona und andere Gesundheitsgefahren-yrb8gSAw8_M.de.vtt',
#  'Warum der Covid19-Lockdown in die gesundheitliche Katastrophe führt-KuZkQWVvinw.de.vtt',
#  'Wie Bill Gates das Weltgesundheitssystem monopolisiert - dt. untertitelt-QVYj1HQyPg0.de.vtt',
#  'ZAPP - Hygienedemos, Sparkurs, Drehs in Zeiten von Corona _ ZAPP _ NDR-GXl6PPr_UmY.de.vtt',
#  '„Coronavirus-Impfstoff - milliardenschwerer Pharma-Profit trotz Gesundheitsrisiken“ Interv. Bigtree-0bhAXcQV8Os.de.vtt',
#  '„Verantwortung in der Krise“-BMNkGoYrdTs.de.vtt']

# %%
import webvtt
def convert_vtt(filenames):    
    #create an assets folder if one does not yet exist
    if os.path.isdir('{}/assets'.format(os.getcwd())) == False:
        os.makedirs('assets')
    #extract the text and times from the vtt file
    for file in filenames:
        captions = webvtt.read(file)
        text_time = pd.DataFrame()
        text_time['text'] = [caption.text for caption in captions]
        text_time['start'] = [caption.start for caption in captions]
        text_time['stop'] = [caption.end for caption in captions]
        text_time.to_csv('assets/{}.csv'.format(file[:-4]),index=False) #-4 to remove '.vtt'
        #remove files from local drive
        os.remove(file)

# %%
#call the function
convert_vtt(filenames_vtt)

# %%
csv_files = [os.fsdecode(file) for file in os.listdir(os.getcwd()+'/assets') if os.fsdecode(file).endswith('.csv')]

# %%
len(csv_files)
# Out:
# 30

# %%
path = 'assets/'
for filename in csv_files:
    os.rename(os.path.join(path, filename), os.path.join(path, filename.replace(' ', '')))
#to verify the results
clean_csv = [os.fsdecode(file) for file in os.listdir(os.getcwd()+'/assets')]
clean_csv[0]
# Out:
# "'Pandemie'!EineschwacheSaisonGrippe!-0uFYpyfYaXQ.de.csv"

# %%
#extract the text and videoid
vidText = []
csv_vidid = []

for file in clean_csv:
   df = pd.read_csv(path+file)
   text = " ".join(df.text)
   vidText.append(text)
   csv_vidid.append(file[-18:-7])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-69-1f6013a90c89> in <module>
#       4
#       5 for file in clean_csv:
# ----> 6    df = pd.read_csv(path+file)
#       7    text = " ".join(df.text)
#       8    vidText.append(text)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: Initializing from file failed

# %%
Gates_Videos.to_csv('GatesVids.csv')
